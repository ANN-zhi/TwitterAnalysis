# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import re

from tqdm import tqdm
from tokenize import tokenize
from clean_tokenizer import tokenize_tweets

# Import module from gsdmm repository
sys.path.insert(0, '../gsdmm/')
from gsdmm import MovieGroupProcess

# %%
# Import preprocessed clean tweet data 
data_dir = r'E:\OneDrive - University of Georgia\Project\Data\tweet_data_3_groccery\4.3 FourColumns 3+1csv - Copy\grocery_2021_tokenized.csv'
tweets_df = pd.read_csv(data_dir) 
tweets_df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
#
#                                                tweet         lon        lat  \
# 0  The BLOCC LIFE Shop is bacc up and running... ... -118.018856  33.975918
# 1  I'm at Costco in North Riverside, IL https://t...  -87.829289  41.846539
#
#         local_time                                        clean_tweet
# 0  1/20/2021 15:59  blocc life shop bacc run sure stop blocc life ...
# 1  1/20/2021 17:59                             costco north riverside

# %% [markdown]
# ### Short Term Text Modeling (STTM)

# %%
tweets_df['clean_tweet'] = tweets_df['clean_tweet'].astype(str)

# Convert cleaned tweet into tokens list
tweets_df['clean_tokens'] = tweets_df.clean_tweet.apply(lambda x: re.split('\s', x))

print(tweets_df['clean_tokens'])
# Out:
# 0         [blocc, life, shop, bacc, run, sure, stop, blo...
# 1                                [costco, north, riverside]
# 2                                                   [foods]
# 3         [see, friend, soror, kroger, pearl, pink, gree...
# 4         [gonna, hate, kodak, home, sign, cancel, steph...
#                                 ...
# 129985    [apparently, people, complain, biden, harris, ...
# 129986    [costco, folsom, california, family, members, ...
# 129987    [important, data, support, safety, goals, bow,...
# 129988              [literally, think, trick, publix, vest]
# 129989                                      [look, package]
# Name: clean_tokens, Length: 129990, dtype: object

# %%
# Create list of tweet tokens
docs = tweets_df['clean_tokens'].tolist()

docs
# Out:
# [['blocc',
#   'life',
#   'shop',
#   'bacc',
#   'run',
#   'sure',
#   'stop',
#   'blocc',
#   'life',
#   'gear',
#   'support',
#   'movement'],
#  ['costco', 'north', 'riverside'],
#  ['foods'],
#  ['see', 'friend', 'soror', 'kroger', 'pearl', 'pink', 'green', 'week'],
#  ['gonna',
#   'hate',
#   'kodak',
#   'home',
#   'sign',
#   'cancel',
#   'stephen',
#   'ross',
#   'micky',
#   'arison',
#   'company',
#   'like',
#   'publix',
#   'chick'],
#  ['unable',
#   'local',
#   'demand',
#   'handle',
#   'high',
#   'theft',
#   'scabbing',
#   'local',
#   'retailers',
#   'walmart',
#   'target',
#   'resort',
#   'ration',
#   'pack',
#   'basketball',
#   'baseball',
#   'pokemon',
#   'card',
#   'nunreal',
#   'card',
#   'market',
#   'continue',
#   'surge',
#   'boom',
#   'bust',
#   'rat'],
#  ['remind', 'tell', 'story', 'hell', 'customer', 'go', 'costco'],
#  ['virus',
#   'transmission',
#   'come',
#   'indoor',
#   'grocery',
#   'store',
#   'home',
#   'depot',
#   'walmart',
#   'construction',
#   'sit',
#   'target',
#   'real'],
#  ['aldi', 'spot', 'carb', 'foods'],
#  ['feel', 'safer', 'park', 'publix', 'mask', 'hat', 'melbourne'],
#  ['publix', 'nbuy', 'nfrom', 'fresh', 'market', 'second', 'rule'],
#  ['wear',
#   'mask',
#   'publix',
#   'point',
#   'pandemic',
#   'dumbass',
#   'hate',
#   'look',
#   'beard',
#   'shirt',
#   'town',
#   'center',
#   'publix'],
#  ['say', 'brand', 'aldi', 'broad', 'fairmount', 'popp'],
#  ['arrive',
#   'today',
#   'collection',
#   'whisky',
#   'whiskey',
#   'plus',
#   'ginormous',
#   'bottle',
#   'costco',
#   'vodka',
#   'costco'],
#  ['gonna',
#   'happen',
#   'gonna',
#   'send',
#   'hoodie',
#   'gonna',
#   'like',
#   'walmart',
#   'money'],
#  ['brookhaven'],
#  ['walmart', 'properly', 'prepare', 'order', 'wouldn', 'clip', 'hoewhale'],
#  ['publix', 'poboys'],
#  ['order',
#   'item',
#   'suppose',
#   'arrive',
#   'early',
#   'email',
#   'push',
#   'rest',
#   'order',
#   'arrive',
#   'miss',
#   'item',
#   'impression',
#   'go',
#   'delay',
#   'item',
#   'decide',
#   'cancel'],
#  ['honestly', 'costco', 'today'],
#  ['swear', 'walk', 'costco', 'minutes', 'cost', 'fail'],
#  ['come',
#   'soon',
#   'store',
#   'near',
#   'drumroll',
#   'excite',
#   'announce',
#   'cider',
#   'available',
#   'foods',
#   'market',
#   'sprout',
#   'nfind',
#   'sprout',
#   'eastlake',
#   'chula',
#   'vista',
#   'locations',
#   'local',
#   'land'],
#  ['spend',
#   'hours',
#   'scan',
#   'items',
#   'clearance',
#   'section',
#   'leave',
#   'store',
#   'hand',
#   'take',
#   'buy',
#   'regular',
#   'items',
#   'right',
#   'shelf',
#   'local',
#   'grocery',
#   'store',
#   'walmart',
#   'target'],
#  ['try', 'mind', 'business', 'albertsons', 'play', 'ready', 'world', 'love'],
#  ['glad', 'apocalypse', 'happen', 'today', 'haven', 'chance', 'costco'],
#  ['publix', 'kinds', 'cheese', 'good', 'say', 'say'],
#  ['sure',
#   'ecological',
#   'decision',
#   'plastic',
#   'bag',
#   'nice',
#   'groceries',
#   'bag',
#   'paper',
#   'kroger'],
#  ['walmart'],
#  ['washington',
#   'post',
#   'kroger',
#   'unknowingly',
#   'funnel',
#   'donations',
#   'militant',
#   'group',
#   'capitol',
#   'riot',
#   'cut',
#   'accident',
#   'good',
#   'see',
#   'holy',
#   'hell',
#   'feel',
#   'like',
#   'shop',
#   'auschwitz'],
#  ['experiment', 'cemita', 'slider', 'roll'],
#  ['target', 'trynna', 'shop', 'midlothian', 'walmart'],
#  ['gonna', 'walmart'],
#  ['story',
#   'material',
#   'love',
#   'miss',
#   'wait',
#   'welcome',
#   'chicken',
#   'tender',
#   'sub',
#   'cities',
#   'open',
#   'stomach'],
#  ['know', 'excite', 'need', 'hope', 'come'],
#  ['matter',
#   'time',
#   'earn',
#   'unemployment',
#   'regulations',
#   'minimum',
#   'wage',
#   'trade',
#   'deal',
#   'go',
#   'stock',
#   'market',
#   'trillions',
#   'stimulus',
#   'prop',
#   'economy',
#   'make',
#   'amazon',
#   'apple',
#   'walmart',
#   'rich',
#   'student',
#   'loan',
#   'commercial',
#   'real',
#   'estate',
#   'problems'],
#  ['wife',
#   'store',
#   'grab',
#   'funfetti',
#   'cake',
#   'case',
#   'bottle',
#   'water',
#   'yeah',
#   'problem',
#   'stop',
#   'kroger',
#   'get',
#   'funfetti',
#   'cake',
#   'case',
#   'bottle',
#   'water',
#   'nwife',
#   'home',
#   'didnt',
#   'ice'],
#  ['soon', 'gonna', 'video', 'scream', 'walmart', 'want', 'mask'],
#  ['series', 'stock'],
#  ['nan'],
#  ['steal',
#   'purse',
#   'joke',
#   'poorest',
#   'bitch',
#   'steal',
#   'gain',
#   'walmart',
#   'purse',
#   'hair',
#   'tie',
#   'advil'],
#  ['dinner', 'years', 'thank', 'north', 'decatur', 'georgia'],
#  ['buy',
#   'foods',
#   'store',
#   'call',
#   'cream',
#   'jubilee',
#   'want',
#   'extend',
#   'heartfelt',
#   'thank',
#   'friendship',
#   'months',
#   'angel'],
#  ['check', 'business', 'stop', 'shop', 'need', 'nretweet', 'help', 'grow'],
#  ['gonna', 'xbox', 'series', 'store', 'online', 'look'],
#  ['happy',
#   'progress',
#   'officials',
#   'publix',
#   'say',
#   'store',
#   'johnson',
#   'city',
#   'hire'],
#  ['meijer', 'livonia'],
#  ['anybody',
#   'feel',
#   'like',
#   'shop',
#   'cart',
#   'ones',
#   'smooth',
#   'cart',
#   'walmart',
#   'instantly',
#   'lottery',
#   'ticket'],
#  ['want', 'hear', 'kroger', 'radio'],
#  ['supercenter', 'henderson'],
#  ['foods', 'vegan', 'sweets'],
#  ['cancel', 'item', 'order', 'restock', 'minutes', 'later'],
#  ['like', 'wont', 'walmart', 'charge', 'cord', 'wish'],
#  ['note', 'girl', 'score', 'park', 'happen', 'costco'],
#  ['see', 'hear', 'walmart', 'cancel', 'inch', 'fantasia', 'mickey', 'happen'],
#  ['bruh',
#   'wait',
#   'line',
#   'costco',
#   'witness',
#   'special',
#   'kind',
#   'dumb',
#   'like',
#   'literally',
#   'light',
#   'tell',
#   'spot',
#   'wide',
#   'open',
#   'dafuq',
#   'doin'],
#  ['shop', 'significant', 'costco', 'know', 'life'],
#  ['walmart', 'sheet'],
#  ['foods', 'market', 'marlton'],
#  ['proud', 'go', 'kroger', 'today', 'wheel'],
#  ['costco', 'nashville'],
#  ['ikea', 'expect', 'universe', 'costco'],
#  ['change', 'good', 'round', 'thank', 'opportunity'],
#  ['nmore',
#   'info',
#   'leader',
#   'high',
#   'skilled',
#   'grit',
#   'wingspan',
#   'nformer',
#   'ncurrent',
#   'nceo',
#   'work',
#   'ncollege',
#   'dropout',
#   'grad',
#   'ride'],
#  ['costco', 'gasoline', 'nashville'],
#  ['clutch',
#   'things',
#   'pandemic',
#   'grocery',
#   'delivery',
#   'thing',
#   'walmart',
#   'literally',
#   'walk',
#   'outside',
#   'porch',
#   'groceries'],
#  ['half',
#   'years',
#   'life',
#   'biggest',
#   'piece',
#   'shit',
#   'company',
#   'work',
#   'miss',
#   'walmart',
#   'family',
#   'think',
#   'time',
#   'year',
#   'away',
#   'hell',
#   'hole'],
#  ['yeah', 'happen', 'walmart', 'surgery', 'center', 'feel', 'cyborgy'],
#  ['ready',
#   'national',
#   'mask',
#   'mandate',
#   'tire',
#   'yell',
#   'republicans',
#   'kroger'],
#  ['favorite', 'food', 'costco', 'make', 'sell', 'tryna'],
#  ['post', 'photo', 'walmart', 'kingsport', 'stone'],
#  ['weirdest',
#   'biden',
#   'inauguration',
#   'reaction',
#   'costco',
#   'entrance',
#   'sing',
#   'gareth',
#   'brook',
#   'songs'],
#  ['yall', 'add', 'kroger'],
#  ['wish', 'sell', 'weed', 'costco'],
#  ['thing', 'wait', 'entire', 'life', 'brazil', 'pack', 'delicioso', 'costco'],
#  ['get', 'costco', 'membership', 'right'],
#  ['vaccines',
#   'mask',
#   'mandate',
#   'copartner',
#   'incompetence',
#   'enforce',
#   'customers',
#   'wear',
#   'mask',
#   'shame'],
#  ['cool', 'happen', 'costco'],
#  ['walmart',
#   'monticello',
#   'yeah',
#   'crazy',
#   'pass',
#   'house',
#   'head',
#   'moms',
#   'feel',
#   'horrible',
#   'pass',
#   'cars',
#   'move',
#   'tap'],
#  ['avoid', 'costco', 'life', 'reason'],
#  ['reposted',
#   'golden',
#   'honey',
#   'dark',
#   'chocolate',
#   'shell',
#   'walmart',
#   'royal',
#   'palm',
#   'beach',
#   'belvedere'],
#  ['damn',
#   'corperate',
#   'walmart',
#   'weeks',
#   'respond',
#   'tweet',
#   'dont',
#   'waste',
#   'time',
#   'tell',
#   'employees',
#   'follow',
#   'tooele',
#   'utah',
#   'right'],
#  ['dollar', 'general', 'jump', 'shoot', 'walmart', 'knee'],
#  ['cup',
#   'costco',
#   'couple',
#   'months',
#   'nthe',
#   'mushroom',
#   'ornament',
#   'currently',
#   'check',
#   'instagram',
#   'post',
#   'sale'],
#  ['imagine', 'meet', 'costco', 'simple'],
#  ['come', 'walmart', 'like', 'like', 'cute', 'seein', 'time', 'trash'],
#  ['buy', 'salmon', 'walmart', 'descriptor', 'pink'],
#  ['see', 'cute', 'costco', 'probably'],
#  ['friend', 'want', 'know', 'sell', 'churros'],
#  ['welcome',
#   'yodelburg',
#   'walmart',
#   'supreme',
#   'chancellor',
#   'currency',
#   'candle',
#   'town',
#   'road',
#   'national',
#   'anthem'],
#  ['note',
#   'letter',
#   'state',
#   'largest',
#   'employer',
#   'country',
#   'largest',
#   'monopoly',
#   'nthat',
#   'note',
#   'clear',
#   'allow',
#   'employees',
#   'unionize',
#   'consumer',
#   'business',
#   'employee',
#   'own'],
#  ['try',
#   'healthier',
#   'office',
#   'decide',
#   'nice',
#   'bring',
#   'comfort',
#   'foods',
#   'single'],
#  ['damn',
#   'security',
#   'person',
#   'short',
#   'stop',
#   'watch',
#   'dont',
#   'replace',
#   'walmart',
#   'luckys',
#   'need',
#   'lawyer',
#   'bono',
#   'seriously',
#   'shit',
#   'stop',
#   'discriminate',
#   'discriminate'],
#  ['excite',
#   'grab',
#   'pack',
#   'toilet',
#   'paper',
#   'walmart',
#   'thisssss',
#   'feel',
#   'like',
#   'sandpaper'],
#  ['yeah', 'thank'],
#  ['brutal', 'graveyard', 'usually', 'better'],
#  ['sham', 'believe'],
#  ['insurmountable',
#   'guilt',
#   'feel',
#   'descend',
#   'apartment',
#   'stairs',
#   'listen',
#   'willie',
#   'cry',
#   'abandonment',
#   'walmart'],
#  ['weird',
#   'froot',
#   'loop',
#   'frost',
#   'flake',
#   'collab',
#   'albertsons',
#   'upset',
#   'frost',
#   'flake',
#   'froot',
#   'loop'],
#  ['costco', 'gasoline', 'norwalk'],
#  ['costco', 'food', 'court', 'norwalk'],
#  ['people',
#   'need',
#   'break',
#   'tech',
#   'giant',
#   'pathetic',
#   'government',
#   'real',
#   'boss',
#   'help',
#   'walmart',
#   'amazon',
#   'business',
#   'amazon',
#   'break',
#   'soon'],
#  ['costco', 'pharmacy', 'norwalk'],
#  ['walk', 'costco', 'star', 'like', 'see', 'time', 'week', 'helpful'],
#  ['know', 'allow', 'refuse', 'wear', 'mask', 'store', 'shop', 'know'],
#  ['costco', 'norwalk'],
#  ['holy',
#   'shit',
#   'fuck',
#   'dumb',
#   'walmart',
#   'troy',
#   'haven',
#   'literally',
#   'years',
#   'bare'],
#  ['break',
#   'biden',
#   'wife',
#   'accidentally',
#   'bump',
#   'wife',
#   'costco',
#   'president'],
#  ['costco', 'gasoline', 'diego'],
#  ['palm', 'beach', 'county'],
#  ['walmart', 'thank', 'legs', 'ashy'],
#  ['discount', 'cod', 'qanon', 'storm', 'website'],
#  ['order', 'pickup', 'arlington', 'till', 'foods', 'market'],
#  ['time',
#   'say',
#   'head',
#   'darkest',
#   'time',
#   'pandemic',
#   'pull',
#   'costco',
#   'instacart'],
#  ['work',
#   'best',
#   'target',
#   'walmart',
#   'fuck',
#   'youu',
#   'cause',
#   'fully',
#   'restock',
#   'xbox',
#   'holiday',
#   'pass'],
#  ['million',
#   'people',
#   'power',
#   'wallet',
#   'boycott',
#   'high',
#   'tech',
#   'monopolies',
#   'namazon',
#   'nwalmart',
#   'nmajor',
#   'company',
#   'support',
#   'democratic',
#   'party',
#   'nchinese',
#   'goods',
#   'nhollywood',
#   'nfox'],
#  ['think', 'learn', 'shop', 'costco', 'hungry'],
#  ['bank', 'mail', 'foods', 'hope', 'popcorn', 'chicken', 'cup', 'today'],
#  ['heartbreak', 'walmart'],
#  ['dear',
#   'canadian',
#   'snowbirds',
#   'nuntil',
#   'recently',
#   'government',
#   'lead',
#   'moron',
#   'governor',
#   'fuckwit',
#   'nthat',
#   'say',
#   'socialize',
#   'medicine',
#   'polite',
#   'line',
#   'publix',
#   'get',
#   'vaccinate',
#   'start',
#   'feel',
#   'certain'],
#  ['home', 'groceries', 'thank', 'mess', 'fail', 'sack'],
#  ['gotta',
#   'swing',
#   'costco',
#   'shots',
#   'renew',
#   'park',
#   'sticker',
#   'know',
#   'drill'],
#  ['shop', 'groceries', 'walmart', 'knowwwwwwwwwws', 'breath', 'stink'],
#  ['buy',
#   'walmart',
#   'sale',
#   'sale',
#   'chromebook',
#   'tell',
#   'couldn',
#   'skoo',
#   'term',
#   'student',
#   'take',
#   'units'],
#  ['important',
#   'news',
#   'nhave',
#   'buy',
#   'food',
#   'item',
#   'sheer',
#   'beauty',
#   'package',
#   'hope',
#   'good',
#   'publix',
#   'super',
#   'market',
#   'hamilton',
#   'place'],
#  ['want',
#   'know',
#   'hour',
#   'photo',
#   'department',
#   'picture',
#   'print',
#   'time',
#   'present',
#   'capitol',
#   'rotunda'],
#  ['get',
#   'unseasoned',
#   'crockpot',
#   'need',
#   'stop',
#   'inauguration',
#   'run',
#   'kroger'],
#  ['parler', 'users', 'walmart', 'shoppers', 'furriousssss'],
#  ['resistence',
#   'boycott',
#   'high',
#   'tech',
#   'monopolies',
#   'nboycott',
#   'namazon',
#   'nwalmart',
#   'ncompanies',
#   'donate',
#   'democratic',
#   'party',
#   'nchinese',
#   'goods',
#   'nhollywood',
#   'nfox',
#   'nfor',
#   'starters'],
#  ['order',
#   'stuff',
#   'things',
#   'order',
#   'walmart',
#   'money',
#   'return',
#   'items',
#   'imma',
#   'return'],
#  ['love',
#   'work',
#   'walmart',
#   'life',
#   'feel',
#   'like',
#   'reality',
#   'care',
#   'bitch',
#   'main',
#   'character'],
#  ['say'],
#  ['days',
#   'injuries',
#   'corporate',
#   'taco',
#   'wednesday',
#   'walmart',
#   'neighborhood',
#   'market',
#   'citrus',
#   'heights'],
#  ['grateful',
#   'gloom',
#   'doom',
#   'west',
#   'wing',
#   'go',
#   'start',
#   'shout',
#   'walmart',
#   'grateful'],
#  ['years',
#   'week',
#   'go',
#   'michigan',
#   'know',
#   'legal',
#   'weed',
#   'till',
#   'days',
#   'buy',
#   'backwood',
#   'preroll',
#   'dude',
#   'walmart',
#   'highest'],
#  ['resident',
#   'world',
#   'california',
#   'honestly',
#   'fuck',
#   'charade',
#   'upset',
#   'blow',
#   'white',
#   'house',
#   'costco',
#   'winco',
#   'employee',
#   'stakeholders'],
#  ['love', 'live', 'away', 'costco'],
#  ['walmart', 'grocery', 'pickup', 'cool', 'feel', 'want', 'help'],
#  ['know',
#   'secret',
#   'santas',
#   'christmas',
#   'layaways',
#   'walmart',
#   'know',
#   'secret',
#   'tooth',
#   'fairy',
#   'kid',
#   'brace'],
#  ['publix', 'covid', 'vaccine', 'crash', 'available', 'friday'],
#  ['mistake',
#   'today',
#   'cute',
#   'publix',
#   'manager',
#   'bag',
#   'groceries',
#   'help',
#   'offer'],
#  ['costco',
#   'roseville',
#   'michigan',
#   'hours',
#   'consumption',
#   'earthbound',
#   'farm',
#   'caesar',
#   'salad',
#   'food',
#   'poison'],
#  ['double',
#   'order',
#   'week',
#   'restock',
#   'dolly',
#   'jolene',
#   'mccartney',
#   'latest',
#   'hendrix',
#   'slowly',
#   'roll',
#   'shop',
#   'excite',
#   'vinyl',
#   'record',
#   'thurs',
#   'nstop'],
#  ['post', 'photo', 'foods', 'market'],
#  ['oooo', 'soon', 'go', 'publix', 'yall', 'need'],
#  ['meijer', 'sure', 'term', 'congress', 'perso'],
#  ['similar', 'issue', 'think', 'things', 'iron'],
#  ['sugary', 'foods', 'shift', 'look', 'like', 'imma', 'marathon', 'burn'],
#  ['finish',
#   'watch',
#   'inauguration',
#   'walk',
#   'coffee',
#   'shop',
#   'play',
#   'stop',
#   'vibe'],
#  ['kamala',
#   'good',
#   'convocation',
#   'stock',
#   'aint',
#   'ones',
#   'come',
#   'walmart',
#   'cents',
#   'lmao'],
#  ['thank', 'toad'],
#  ['open',
#   'door',
#   'nfor',
#   'hardly',
#   'storm',
#   'capitol',
#   'narrative',
#   'shit',
#   'fuck',
#   'outta',
#   'walmart',
#   'better',
#   'security',
#   'capitol',
#   'think',
#   'moment',
#   'nevermind',
#   'turn',
#   'volume',
#   'think',
#   'tell'],
#  ['costco', 'gasoline', 'diego'],
#  ['work', 'switch', 'costco', 'water', 'arrowhead', 'place', 'hire'],
#  ['free',
#   'wawa',
#   'publix',
#   'foods',
#   'wegmans',
#   'food',
#   'lion',
#   'pick',
#   'richmond',
#   'trust',
#   'family',
#   'lifestyle',
#   'magazine'],
#  ['wonder',
#   'target',
#   'walmart',
#   'best',
#   'money',
#   'today',
#   'tomorrow',
#   'know',
#   'proud',
#   'boys',
#   'break',
#   'today'],
#  ['nigga', 'walmart', 'open', 'garlic', 'bread', 'close'],
#  ['go', 'shop', 'walmart'],
#  ['hate',
#   'make',
#   'assumptions',
#   'customers',
#   'look',
#   'like',
#   'damn',
#   'diabetes',
#   'contagious',
#   'right',
#   'kroger'],
#  ['surprise', 'buy', 'walmart'],
#  ['slowly', 'replace', 'wardrobe', 'clothe', 'costco', 'pandemic'],
#  ['cute', 'goth', 'girl', 'walmart', 'self', 'check'],
#  ['soon', 'hershey', 'chocolate', 'retailer', 'near', 'walmart', 'plainwell'],
#  ['order',
#   'maternity',
#   'bras',
#   'walmart',
#   'bitch',
#   'send',
#   'blades',
#   'blender'],
#  ['thank', 'action'],
#  ['kissimmee'],
#  ['complain',
#   'need',
#   'solutions',
#   'nboycott',
#   'high',
#   'tech',
#   'monopolies',
#   'namazon',
#   'nwalmart',
#   'nall',
#   'major',
#   'company',
#   'support',
#   'democratic',
#   'party',
#   'nchinese',
#   'import',
#   'nhollywood'],
#  ['cashier', 'local', 'walmart', 'take', 'inauguration'],
#  ['eat',
#   'random',
#   'foods',
#   'right',
#   'historic',
#   'moment',
#   'happen',
#   'expect',
#   'work',
#   'time'],
#  ['talk',
#   'price',
#   'continue',
#   'effect',
#   'retail',
#   'zero',
#   'sight',
#   'level',
#   'toxicity',
#   'walmart',
#   'target',
#   'week',
#   'erratic',
#   'hobby',
#   'price',
#   'make',
#   'retail',
#   'valuable',
#   'volatile'],
#  ['come'],
#  ['boycott',
#   'high',
#   'tech',
#   'monopolies',
#   'namazon',
#   'nwalmart',
#   'nall',
#   'businesses',
#   'donate',
#   'democratic',
#   'party',
#   'nthe',
#   'chinese',
#   'import',
#   'nhollywood',
#   'nlet',
#   'start',
#   'nlgs'],
#  ['walmart', 'list', 'vibes'],
#  ['storm',
#   'build',
#   'today',
#   'lmdao',
#   'tough',
#   'gonna',
#   'walmart',
#   'lot',
#   'kill',
#   'white',
#   'continue',
#   'white',
#   'white',
#   'crime',
#   'meth',
#   'shit'],
#  ['zillow',
#   'look',
#   'like',
#   'try',
#   'walmart',
#   'amazon',
#   'real',
#   'estate',
#   'obviously',
#   'choose',
#   'want',
#   'help',
#   'sell',
#   'house',
#   'company',
#   'take',
#   'stop',
#   'competitio'],
#  ['meat', 'today', 'warehouse', 'supercenter', 'avon', 'park'],
#  ['kroger', 'give', 'money', 'damn', 'check', 'go', 'kroger', 'landlord'],
#  ['breastfeed',
#   'room',
#   'tell',
#   'damn',
#   'sardine',
#   'anymore',
#   'walmart',
#   'frisco'],
#  ['bernie', 'pull', 'walmart', 'finna', 'catch', 'cold'],
#  ['walmart', 'check', 'line'],
#  ['post', 'photo', 'walmart', 'alpharetta', 'windward', 'pkwy'],
#  ['bernie', 'want', 'sample', 'costco'],
#  ['yeah', 'walmart', 'soooo', 'shady', 'kroger', 'kroger', 'substitute'],
#  ['mark',
#   'bizzelle',
#   'chairman',
#   'paycheck',
#   'entainment',
#   'charles',
#   'schwab',
#   'industrial',
#   'valley',
#   'bank',
#   'hilton',
#   'holiday',
#   'ramada',
#   'nordstom',
#   'pot',
#   'food',
#   'bronx',
#   'linkendin',
#   'business',
#   'skype',
#   'kmart',
#   'pharmacy',
#   'walmart',
#   'greyhound'],
#  ['obviously', 'costco'],
#  ['shut',
#   'nboycott',
#   'nhigh',
#   'tech',
#   'monopolies',
#   'namazon',
#   'nwalmart',
#   'nchinese',
#   'goods',
#   'supporters',
#   'democrats',
#   'nhollywood',
#   'nfor',
#   'starters'],
#  ['rack',
#   'gardein',
#   'products',
#   'good',
#   'vegan',
#   'brand',
#   'publix',
#   'free',
#   'deal',
#   'go',
#   'today',
#   'stock'],
#  ['want', 'local', 'foods', 'steal', 'almonds'],
#  ['supercenter', 'port', 'richey'],
#  ['representatives',
#   'outside',
#   'kroger',
#   'near',
#   'house',
#   'yesterday',
#   'sweet',
#   'pleasant',
#   'ladies'],
#  ['like',
#   'hella',
#   'dress',
#   'bernie',
#   'wear',
#   'weatherproof',
#   'costco',
#   'jacket'],
#  ['walmart'],
#  ['dear', 'change', 'sale', 'thank'],
#  ['costco', 'size', 'bottle', 'break', 'queen', 'gotchu'],
#  ['clinton',
#   'wannabe',
#   'obama',
#   'remix',
#   'today',
#   'saxophones',
#   'administration',
#   'walmart',
#   'prison',
#   'shit'],
#  ['early', 'wild'],
#  ['thank',
#   'hadn',
#   'see',
#   'notice',
#   'friday',
#   'happen',
#   'know',
#   'appointments',
#   'able',
#   'book'],
#  ['hate', 'go', 'walmart'],
#  ['love', 'hear', 'misery', 'business', 'play', 'kroger', 'years', 'later'],
#  ['foods', 'rich', 'wawa', 'rest', 'make', 'sense'],
#  ['get', 'martinellis', 'stop', 'shop', 'merrick'],
#  ['publix', 'broward', 'county', 'fantastic', 'broward', 'county'],
#  ['foods', 'gulity', 'pleasure', 'like', 'love'],
#  ['dude', 'walmart', 'brand', 'kara', 'wild', 'catch', 'outside', 'bout'],
#  ['great', 'value', 'brand', 'frost', 'flake', 'walmart', 'hit', 'different'],
#  ['chris', 'need', 'join', 'club', 'black', 'sock', 'costco'],
#  ['excite', 'kansas', 'city', 'trip', 'say', 'go', 'walmart', 'table', 'need'],
#  ['person', 'lean', 'walmart', 'fuck', 'honk', 'horn'],
#  ['droppin', 'today'],
#  ['good', 'morning', 'happy', 'wednesday', 'publix', 'port', 'orange'],
#  ['catch', 'kroger', 'groudon', 'wild', 'read', 'issue', 'reply', 'fire'],
#  ['carb', 'binge', 'eat', 'food', 'court'],
#  ['brisket',
#   'costco',
#   'good',
#   'price',
#   'briskets',
#   'slightly',
#   'expensive',
#   'restaurant',
#   'depot',
#   'stick',
#   'costco',
#   'better',
#   'grade',
#   'expensive',
#   'experiment'],
#  ['intrigue', 'great'],
#  ['cashews', 'fancy', 'cookies', 'costco'],
#  ['start',
#   'today',
#   'take',
#   'appointments',
#   'publix',
#   'go',
#   'counties',
#   'fully',
#   'book'],
#  ['parent',
#   'drive',
#   'hours',
#   'finally',
#   'vaccine',
#   'appointment',
#   'thank',
#   'jumble',
#   'appointment',
#   'farther',
#   'county',
#   'originally',
#   'select'],
#  ['manu', 'future', 'reference', 'meijer', 'pronounce'],
#  ['prolly',
#   'right',
#   'dicks',
#   'talk',
#   'advantage',
#   'obvious',
#   'opportunity',
#   'walmart',
#   'academy',
#   'employees',
#   'prolly',
#   'realize',
#   'bill',
#   'play'],
#  ['piss', 'forget', 'cheese', 'stick', 'kroger', 'night'],
#  ['bulk',
#   'pack',
#   'gummy',
#   'bear',
#   'honestly',
#   'worth',
#   'costco',
#   'membership',
#   'time'],
#  ['date', 'walmart', 'honestly', 'need', 'self', 'checkout'],
#  ['guess',
#   'depend',
#   'house',
#   'motivation',
#   'public',
#   'throw',
#   'food',
#   'lion',
#   'chicken',
#   'patties',
#   'ramen',
#   'noodles',
#   'spaghetti',
#   'sauce',
#   'mozzarella',
#   'cheap',
#   'single',
#   'food'],
#  ['think',
#   'neurosurgeon',
#   'walmart',
#   'worker',
#   'pay',
#   'equally',
#   'obviously',
#   'understand',
#   'difference',
#   'job',
#   'answer',
#   'walmart',
#   'worker',
#   'brain',
#   'surgery',
#   'lawsuits',
#   'eligible',
#   'socialism',
#   'explain'],
#  ['target', 'walmart'],
#  ['know'],
#  ['quit'],
#  ['help', 'console', 'crisis'],
#  ['costco',
#   'seattle',
#   'washington',
#   'chicken',
#   'ling',
#   'ling',
#   'potstickers',
#   'lunch',
#   'destroy',
#   'wife',
#   'fail',
#   'mention',
#   'sick',
#   'days',
#   'food',
#   'poison'],
#  ['besties',
#   'run',
#   'press',
#   'shop',
#   'coffee',
#   'best',
#   'years',
#   'weren',
#   'sure',
#   'clock',
#   'wouldn',
#   'stop',
#   'run',
#   'actually',
#   'brief',
#   'veep',
#   'thrill',
#   'regular',
#   'occurrence'],
#  ['walmart', 'supercenter', 'north', 'lauderdale'],
#  ['kind',
#   'hop',
#   'drag',
#   'white',
#   'house',
#   'like',
#   'scream',
#   'toddler',
#   'walmart',
#   'wouldn',
#   'happen',
#   'leave',
#   'early',
#   'morning',
#   'anybody',
#   'wake'],
#  ['kroger',
#   'poplar',
#   'near',
#   'poplar',
#   'plaza',
#   'best',
#   'bruh',
#   'week',
#   'schoo'],
#  ['think', 'brooklyn', 'think', 'granby', 'stop', 'shop'],
#  ['handle',
#   'shit',
#   'think',
#   'pass',
#   'till',
#   'like',
#   'july',
#   'work',
#   'house',
#   'zero'],
#  ['nan'],
#  ['thank'],
#  ['idea',
#   'covid',
#   'vaccine',
#   'sign',
#   'florida',
#   'know',
#   'manage',
#   'online',
#   'sale'],
#  ['amen', 'cause', 'work', 'walmart'],
#  ['update',
#   'sausage',
#   'patties',
#   'good',
#   'boar',
#   'head',
#   'patties',
#   'sale',
#   'stop',
#   'shop',
#   'recommend',
#   'pick'],
#  ['available',
#   'covid',
#   'vaccine',
#   'appointments',
#   'publix',
#   'pharmacy',
#   'claim',
#   'start',
#   'friday',
#   'january',
#   'eligible',
#   'customers',
#   'access',
#   'appointment',
#   'availability',
#   'begin',
#   'saturday',
#   'january'],
#  ['today', 'governor', 'announce', 'order', 'publix', 'vaccine', 'website'],
#  ['nan'],
#  ['crash'],
#  ['registration', 'websites', 'work', 'efficiently', 'discover', 'vaccine'],
#  ['wait', 'queue', 'hour', 'appts', 'book', 'know', 'go', 'happen', 'easier'],
#  ['father',
#   'high',
#   'risk',
#   'monroe',
#   'cnty',
#   'online',
#   'queue',
#   'hour',
#   'morning',
#   'mobile',
#   'crash',
#   'queue',
#   'resolve',
#   'sign',
#   'vaccine'],
#  ['bummer',
#   'minutes',
#   'lilly',
#   'pulitzer',
#   'online',
#   'sale',
#   'eventually',
#   'skort'],
#  ['understand',
#   'limit',
#   'vaccine',
#   'supply',
#   'million',
#   'people',
#   'waste',
#   'hour',
#   'try',
#   'fail',
#   'tomorrow'],
#  ['spend',
#   'minutes',
#   'morning',
#   'publix',
#   'queue',
#   'vaccine',
#   'appt',
#   'vaccine',
#   'insufficient',
#   'ridiculous',
#   'desantis',
#   'pandemic',
#   'solutions',
#   'laughable',
#   'maybe',
#   'rich',
#   'canadian'],
#  ['design'],
#  ['order',
#   'unbleached',
#   'coffee',
#   'filter',
#   'arrive',
#   'tomorrow',
#   'stupidly',
#   'pass',
#   'kroger',
#   'yesterday',
#   'think',
#   'plenty',
#   'make',
#   'coffee',
#   'see',
#   'filter',
#   'cabinet'],
#  ['like',
#   'book',
#   'appointment',
#   'websites',
#   'try',
#   'hour',
#   'book',
#   'publix',
#   'site',
#   'morning',
#   'want',
#   'read',
#   'great'],
#  ['thank', 'keep', 'awake', 'engage', 'hope', 'camp', 'slot', 'want'],
#  ['heck',
#   'publix',
#   'vaccine',
#   'site',
#   'wait',
#   'hour',
#   'half',
#   'error',
#   'website',
#   'crash'],
#  ['wait', 'queue', 'minutes', 'covid', 'message'],
#  ['chik', 'filet', 'better', 'vaccine', 'appointments', 'publix'],
#  ['people', 'frustration', 'poor', 'responsibility'],
#  ['lucky'],
#  ['sure', 'super', 'phone', 'number', 'suck'],
#  ['wish', 'vaccine', 'amazon', 'prime', 'know', 'website', 'work'],
#  ['start', 'feel', 'publix', 'queue', 'probably', 'appt'],
#  ['know', 'right', 'write', 'jinx'],
#  ['secure',
#   'open',
#   'fair',
#   'elections',
#   'nrecall',
#   'vote',
#   'trump',
#   'house',
#   'senate',
#   'nboycott',
#   'advertisers',
#   'high',
#   'tech',
#   'monopolies',
#   'namazon',
#   'walmart',
#   'nstop',
#   'buy',
#   'chinese',
#   'goods',
#   'send',
#   'illegals',
#   'republican',
#   'reeducation',
#   'camp'],
#  ['go', 'palm', 'beach'],
#  ['post', 'photo', 'walmart', 'pleasant', 'proprietors'],
#  ['go',
#   'sure',
#   'palm',
#   'beach',
#   'show',
#   'available',
#   'little',
#   'road',
#   'trip',
#   'kind',
#   'think',
#   'go',
#   'happen'],
#  ['online', 'parent', 'vaccine', 'appointment', 'mess', 'department'],
#  ['enter', 'page', 'right', 'hour'],
#  ['expect',
#   'long',
#   'wait',
#   'happy',
#   'recognize',
#   'need',
#   'charlotte',
#   'county',
#   'send',
#   'vaccines',
#   'protect',
#   'people',
#   'population'],
#  ['point', 'want', 'mins'],
#  ['step', 'dial', 'phone', 'number', 'week', 'random', 'time'],
#  ['boot',
#   'covid',
#   'vaccine',
#   'appt',
#   'website',
#   'go',
#   'live',
#   'wait',
#   'queue',
#   'county',
#   'fully',
#   'book'],
#  ['sadly', 'bummer', 'winner', 'today'],
#  ['think',
#   'refresh',
#   'page',
#   'sign',
#   'device',
#   'show',
#   'fully',
#   'book',
#   'covid',
#   'vaccine',
#   'florida'],
#  ['right', 'thank'],
#  ['charlotte', 'county', 'fully', 'book'],
#  ['think', 'large', 'button', 'scree'],
#  ['like', 'designer', 'good', 'travel', 'walmart', 'tights', 'flip', 'flop'],
#  ['minutes', 'charlotte', 'county', 'fully', 'book', 'nnow', 'wait', 'round'],
#  ['charlotte', 'county', 'sell'],
#  ['hope', 'county'],
#  ['think',
#   'trick',
#   'eye',
#   'screen',
#   'refresh',
#   'notice',
#   'charlotte',
#   'show',
#   'fully',
#   'book',
#   'rest',
#   'apts',
#   'available',
#   'good',
#   'luck'],
#  ['congrats', 'caller'],
#  ['see', 'people'],
#  ['faith', 'better', 'call', 'phone', 'number', 'right'],
#  ['trump',
#   'version',
#   'soviet',
#   'bread',
#   'line',
#   'sit',
#   'dawn',
#   'queue',
#   'try',
#   'register',
#   'covid',
#   'vaccine',
#   'publix',
#   'information',
#   'step',
#   'long',
#   'line',
#   'madden'],
#  ['leave', 'room'],
#  ['queue', 'help', 'friend', 'finger', 'cross'],
#  ['hear', 'get', 'congrats'],
#  ['bright',
#   'boyfriend',
#   'walmart',
#   'panda',
#   'walk',
#   'grab',
#   'size',
#   'start',
#   'walk',
#   'fruit',
#   'section'],
#  ['queue', 'covid', 'vaccine', 'florida'],
#  ['kid', 'register'],
#  ['remind', 'walmart', 'pics', 'hang', 'parent', 'house'],
#  ['glad'],
#  ['sign', 'go', 'meijer'],
#  ['come', 'publix', 'fail'],
#  ['publix',
#   'vaccine',
#   'sign',
#   'mess',
#   'sit',
#   'queue',
#   'minutes',
#   'probably',
#   'tell',
#   'appts',
#   'fill',
#   'minute'],
#  ['costco', 'pizza'],
#  ['total',
#   'disgrace',
#   'wayne',
#   'offense',
#   'anytime',
#   'person',
#   'steal',
#   'iphone',
#   'walmart',
#   'lock',
#   'fair',
#   'rapper',
#   'bust',
#   'conspiracy',
#   'murder',
#   'pardon',
#   'person',
#   'child',
#   'support',
#   'prison'],
#  ['fast', 'love', 'curve', 'nail', 'food', 'lion', 'days'],
#  ['uncle',
#   'go',
#   'walmart',
#   'christmas',
#   'look',
#   'loudest',
#   'annoy',
#   'possible',
#   'toy'],
#  ['today',
#   'participate',
#   'south',
#   'carolina',
#   'publix',
#   'locations',
#   'begin',
#   'administer',
#   'covid',
#   'vaccines',
#   'online',
#   'appointments',
#   'open',
#   'yesterday',
#   'miss',
#   'publix',
#   'say',
#   'live',
#   'challenge',
#   'woman',
#   'face',
#   'line'],
#  ['walmart', 'close', 'years', 'china', 'traitors'],
#  ['mental',
#   'image',
#   'head',
#   'donald',
#   'trump',
#   'drug',
#   'white',
#   'house',
#   'legs',
#   'like',
#   'scream',
#   'toddler',
#   'walmart',
#   'happe'],
#  ['walmart'],
#  ['publix', 'mojo', 'oven', 'roast', 'chicken', 'sham'],
#  ['pretty', 'work', 'kroger', 'think'],
#  ['dear',
#   'start',
#   'offer',
#   'deal',
#   'line',
#   'phone',
#   'walmart',
#   'maybe',
#   'bogo',
#   'deal'],
#  ['want', 'thing', 'spend', 'shit'],
#  ['walmart'],
#  ['need', 'tide', 'asap'],
#  ['remind', 'costco', 'supermarket', 'specially', 'costco', 'hungry'],
#  ['meijer', 'mins', 'store', 'mins', 'snow', 'inch', 'mins'],
#  ['mypillow',
#   'different',
#   'boycott',
#   'nike',
#   'keurig',
#   'walmart',
#   'netflix',
#   'target',
#   'budweiser',
#   'starbucks',
#   'right',
#   'nprivate',
#   'company',
#   'private',
#   'citizens',
#   'government',
#   'censorship',
#   'freedom',
#   'speech',
#   'freedom',
#   'consequence'],
#  ['niggas', 'stay', 'walmart'],
#  ['locate',
#   'store',
#   'like',
#   'costco',
#   'definitely',
#   'ways',
#   'increase',
#   'batch',
#   'number'],
#  ['biggest', 'secrets', 'journeyman', 'bricklayer'],
#  ['myth',
#   'tell',
#   'possession',
#   'magical',
#   'key',
#   'lead',
#   'forget',
#   'city',
#   'dorado',
#   'hand',
#   'key',
#   'answer',
#   'riddle',
#   'puzzle'],
#  ['ndispatch',
#   'medical',
#   'service',
#   'walmart',
#   'rainier',
#   'renton',
#   'nresponding',
#   'dept',
#   'renton',
#   'nunit'],
#  ['shout',
#   'home',
#   'girl',
#   'score',
#   'covid',
#   'test',
#   'walmart',
#   'get',
#   'negative',
#   'sana',
#   'sana',
#   'colita',
#   'rana',
#   'mystical',
#   'heal',
#   'chant',
#   'ancestors',
#   'pass',
#   'deserve',
#   'prop'],
#  ['read',
#   'amazon',
#   'walmart',
#   'face',
#   'issue',
#   'grow',
#   'business',
#   'base',
#   'dumb',
#   'narrative'],
#  ['try',
#   'grocery',
#   'delivery',
#   'consider',
#   'sick',
#   'snow',
#   'place',
#   'order',
#   'expect',
#   'delivery',
#   'tell',
#   'cancel',
#   'reorder',
#   'wait',
#   'tomorrow'],
#  ['foods', 'market', 'kailua'],
#  ['supercenter', 'chandler'],
#  ['wanna', 'know', 'sell', 'costco', 'cause', 'wanna', 'alot'],
#  ['throw', 'little', 'bussy', 'shake', 'like', 'walmart'],
#  ['stupid',
#   'leave',
#   'wing',
#   'situation',
#   'see',
#   'kroger',
#   'store',
#   'costco',
#   'military',
#   'commissaries'],
#  ['foods', 'curry', 'chicken', 'salad', 'hit', 'right', 'wednesday', 'even'],
#  ['add',
#   'costco',
#   'list',
#   'look',
#   'gonna',
#   'get',
#   'bread',
#   'machine',
#   'coffee',
#   'machine',
#   'order',
#   'better',
#   'perfect',
#   'coffee',
#   'fresh',
#   'bread',
#   'butter'],
#  ['tonight',
#   'look',
#   'happen',
#   'monday',
#   'biscayne',
#   'criminal',
#   'mischief',
#   'report',
#   'write',
#   'arrest',
#   'cop',
#   'appear',
#   'video',
#   'share'],
#  ['watch', 'freak', 'funny', 'online'],
#  ['ribeye', 'veggies'],
#  ['walmart', 'morning', 'shout', 'have', 'cuticle', 'pushers', 'nail'],
#  ['post', 'photo', 'walmart', 'supercenter', 'cape', 'girardeau'],
#  ['post', 'photo', 'foods', 'market'],
#  ['store',
#   'self',
#   'checkout',
#   'station',
#   'check',
#   'items',
#   'pay',
#   'price',
#   'expensive',
#   'check',
#   'like',
#   'discount',
#   'good',
#   'walmart'],
#  ['post', 'photo', 'walmart', 'supercenter', 'cape', 'girardeau'],
#  ['costco', 'soda', 'chip'],
#  ['post', 'photo', 'walmart', 'supercenter', 'cape', 'girardeau'],
#  ['post', 'photo', 'walmart', 'supercenter', 'cape', 'girardeau'],
#  ['costco', 'good', 'food'],
#  ['great', 'crossmark', 'walmart', 'retail', 'merchandiser', 'time'],
#  ['costco', 'years', 'go', 'like', 'months'],
#  ['thank',
#   'reply',
#   'alexa',
#   'great',
#   'rest',
#   'night',
#   'check',
#   'foods',
#   'carmel',
#   'weekend'],
#  ['play', 'division', 'walmart'],
#  ['buy', 'ashwagandha', 'herb', 'stress', 'costco', 'maybe', 'google'],
#  ['love',
#   'foods',
#   'items',
#   'comprehensive',
#   'meal',
#   'veggie',
#   'meatballs',
#   'chickpea',
#   'curry',
#   'spanish',
#   'rice',
#   'cornbread',
#   'tell',
#   'figure',
#   'rest'],
#  ['plan', 'pick', 'time', 'costco', 'want', 'story', 'true'],
#  ['need', 'restock', 'asap', 'people', 'need', 'wear', 'game'],
#  ['vogue', 'foods', 'impression'],
#  ['visualize', 'beef', 'stew', 'soup', 'undecided'],
#  ['colorado', 'make', 'live', 'aldi', 'college', 'weeks', 'groceries'],
#  ['look', 'work', 'columbus', 'check'],
#  ['people',
#   'week',
#   'work',
#   'tinnitus',
#   'foods',
#   'help',
#   'symptoms',
#   'pull',
#   'imagine',
#   'carry'],
#  ['pay', 'costco', 'carlsbad', 'good'],
#  ['tonight',
#   'go',
#   'dream',
#   'sufjan',
#   'stevens',
#   'eat',
#   'costco',
#   'sheet',
#   'cake',
#   'bare',
#   'hand'],
#  ['welp',
#   'cultural',
#   'milestone',
#   'write',
#   'costco',
#   'sheet',
#   'cake',
#   'live',
#   'infamy'],
#  ['tell', 'contemplate', 'drive', 'wall', 'lie'],
#  ['look', 'work', 'check'],
#  ['go', 'twice', 'guess', 'stag'],
#  ['macarthur',
#   'officially',
#   'hours',
#   'wait',
#   'online',
#   'grocery',
#   'pickup',
#   'go',
#   'seven',
#   'stag',
#   'grief',
#   'twice'],
#  ['actually',
#   'check',
#   'clearwater',
#   'publix',
#   'today',
#   'little',
#   'light',
#   'paper',
#   'towel',
#   'loaves',
#   'bread',
#   'load',
#   'produce',
#   'shelf',
#   'crowd'],
#  ['food',
#   'costco',
#   'tumwater',
#   'mercury',
#   'test',
#   'food',
#   'dolphin',
#   'safe',
#   'cat',
#   'cat',
#   'justcare',
#   'animal',
#   'rescue',
#   'sanctuary',
#   'like'],
#  ['idea',
#   'damage',
#   'control',
#   'absolutely',
#   'dreadful',
#   'need',
#   'send',
#   'proof',
#   'initial',
#   'person',
#   'sign',
#   'package',
#   'different',
#   'house',
#   'match',
#   'tenant',
#   'lease',
#   'know',
#   'wrong',
#   'house'],
#  ['truly',
#   'surprise',
#   'florida',
#   'visit',
#   'sister',
#   'brother',
#   'true',
#   'nyer',
#   'think',
#   'live',
#   'hear',
#   'feltman',
#   'change',
#   'tomorrow',
#   'go',
#   'publix',
#   'pick',
#   'pack'],
#  ['costco'],
#  ['recommend'],
#  ['costco'],
#  ['wait', 'file', 'tax', 'walmart', 'bag', 'groceries', 'year'],
#  ['toledo'],
#  ['pick', 'order', 'target', 'tomorrow', 'right', 'costco', 'run', 'churro'],
#  ['sure',
#   'local',
#   'market',
#   'baskets',
#   'theyre',
#   'walmart',
#   'online',
#   'super',
#   'good',
#   'sammies'],
#  ['know', 'walmart', 'crowd', 'alamo', 'ranch', 'freeze'],
#  ['hell', 'kroger', 'cheaper'],
#  ['chase',
#   'stop',
#   'shop',
#   'run',
#   'special',
#   'promotion',
#   'incentivize',
#   'cart',
#   'return',
#   'tonight',
#   'free',
#   'waffle',
#   'fry',
#   'supply'],
#  ['kroger', 'plus', 'card', 'member', 'cheaper'],
#  ['costco', 'like', 'weeks'],
#  ['sacramento'],
#  ['experience', 'kroger'],
#  ['hire', 'read', 'latest', 'open', 'truck', 'unloader'],
#  ['costco', 'control', 'food'],
#  ['kroger', 'mold', 'bell', 'pepper'],
#  ['death', 'regret', 'spend', 'time', 'walmart'],
#  ['walmart', 'supercenter', 'mission'],
#  ['food', 'lion', 'union', 'charlotte'],
#  ['walmart', 'grocery', 'pickup', 'delivery', 'plano'],
#  ['feature',
#   'request',
#   'possible',
#   'checkbox',
#   'radio',
#   'button',
#   'coupons',
#   'arrive',
#   'check',
#   'pickup',
#   'order',
#   'save',
#   'employees',
#   'extra',
#   'trip',
#   'call',
#   'bring',
#   'order'],
#  ['go',
#   'shop',
#   'local',
#   'food',
#   'lion',
#   'raleigh',
#   'able',
#   'shop',
#   'list',
#   'people',
#   'hoard',
#   'storm'],
#  ['great', 'crossmark', 'walmart', 'retail', 'merchandiser', 'time'],
#  ['nan'],
#  ['act',
#   'like',
#   'jack',
#   'walmart',
#   'walmart',
#   'clarksville',
#   'veterans',
#   'pkwy'],
#  ['fuck', 'sick', 'walmart', 'open', 'anymore'],
#  ['tell',
#   'gifford',
#   'proud',
#   'extraordinary',
#   'talents',
#   'humble',
#   'juggle',
#   'work',
#   'time',
#   'publix',
#   'maintain',
#   'straight',
#   'teach',
#   'years',
#   'lucky'],
#  ['cake', 'tonight', 'incredible'],
#  ['troll',
#   'whooo',
#   'mannns',
#   'diss',
#   'gonna',
#   'flex',
#   'gram',
#   'fendi',
#   'jacket',
#   'pant',
#   'boot',
#   'match',
#   'seeee',
#   'walmart',
#   'beals',
#   'tjmaxx',
#   'marshalls',
#   'thrift',
#   'store',
#   'drip',
#   'warm',
#   'money',
#   'leave'],
#  ['try',
#   'walmart',
#   'grocery',
#   'delivery',
#   'time',
#   'aaaaand',
#   'deliver',
#   'groceries',
#   'wrong',
#   'house'],
#  ['costco', 'research'],
#  ['sport', 'relate', 'card', 'walmart', 'reach'],
#  ['walmart',
#   'marie',
#   'callender',
#   'delavan',
#   'wisconsin',
#   'marie',
#   'calender',
#   'sweet',
#   'sour',
#   'chicken',
#   'food',
#   'poison'],
#  ['teach',
#   'alchemy',
#   'spend',
#   'time',
#   'research',
#   'cure',
#   'skooma',
#   'addiction'],
#  ['crazy', 'crave', 'cookie', 'triple', 'stuff', 'chocolate', 'stop', 'shop'],
#  ['welcome', 'costco', 'love'],
#  ['woman',
#   'critically',
#   'injure',
#   'shoot',
#   'outside',
#   'walmart',
#   'chantilly',
#   'parkway'],
#  ['typo'],
#  ['post', 'photo', 'costco'],
#  ['food', 'lion', 'single', 'yard', 'pimp', 'chicken', 'freeze'],
#  ['huge',
#   'family',
#   'size',
#   'bugle',
#   'walmart',
#   'imagine',
#   'huge',
#   'members',
#   'family'],
#  ['stop', 'shop'],
#  ['like', 'foods', 'hudson', 'yards', 'foods', 'bryant', 'park', 'favorites'],
#  ['misspell', 'frosty', 'cereal'],
#  ['know', 'love', 'publix'],
#  ['lena', 'meijer', 'death', 'bring', 'emptiness'],
#  ['latest', 'pick'],
#  ['literally', 'home', 'food', 'lion', 'different', 'tomorrow'],
#  ['collapse', 'knees', 'walmart'],
#  ['president', 'love', 'work', 'aldi'],
#  ['thank', 'city', 'center'],
#  ['sic',
#   'push',
#   'hard',
#   'instead',
#   'simply',
#   'treat',
#   'workers',
#   'respect',
#   'sic',
#   'crime',
#   'support',
#   'yall',
#   'hear',
#   'yall',
#   'yall'],
#  ['boysmom', 'safely', 'walmart', 'head', 'directly', 'home', 'sigh'],
#  ['foods'],
#  ['want', 'work', 'crossmark', 'hire', 'click', 'detail'],
#  ['look', 'work', 'check'],
#  ['great', 'crossmark', 'walmart', 'retail', 'merchandiser', 'time'],
#  ['want', 'work', 'meijer', 'hire', 'click', 'detail'],
#  ['food', 'lion', 'get', 'insane'],
#  ['good', 'build', 'costco', 'area', 'live'],
#  ['recommend', 'crossmark', 'walmart', 'retail', 'merchandiser', 'time'],
#  ['tank', 'costco', 'point', 'isabel'],
#  ['online', 'occasionally', 'walmart', 'cost', 'fortune'],
#  ['costco',
#   'money',
#   'year',
#   'mental',
#   'torture',
#   'data',
#   'report',
#   'solitary',
#   'confinement',
#   'mind',
#   'weeks',
#   'year',
#   'damn',
#   'stop',
#   'put',
#   'money',
#   'life',
#   'health',
#   'peace',
#   'mind'],
#  ['beer', 'foods', 'time'],
#  ['love', 'espresso', 'chocolate', 'chip', 'daughter'],
#  ['claim', 'downtown', 'publix'],
#  ['interest', 'great'],
#  ['publix', 'favorite', 'wednesday'],
#  ['come',
#   'stop',
#   'shop',
#   'quality',
#   'staff',
#   'service',
#   'nswipe',
#   'leave',
#   'photoshoot',
#   'today',
#   'franky',
#   'diamonds'],
#  ['foods', 'drop', 'major', 'bread', 'vitamins', 'nutrients'],
#  ['ortho',
#   'write',
#   'similar',
#   'letter',
#   'walmart',
#   'worker',
#   'compensation',
#   'carrier',
#   'refuse',
#   'replace',
#   'shoulder',
#   'surgeries',
#   'literally',
#   'threaten',
#   'malpractice',
#   'shiny',
#   'titanium',
#   'shoulder',
#   'replacement',
#   'month',
#   'later'],
#  ['grocery', 'delivery', 'service', 'earlier', 'easy'],
#  ['walmart', 'lysol', 'mango', 'hibiscus', 'spray', 'nholy', 'shit'],
#  ['come',
#   'stop',
#   'shop',
#   'quality',
#   'staff',
#   'service',
#   'nswipe',
#   'leave',
#   'photoshoot',
#   'today',
#   'franky',
#   'diamonds'],
#  ['dixie',
#   'kroger',
#   'line',
#   'literally',
#   'aisle',
#   'wrap',
#   'store',
#   'shelve',
#   'pretty',
#   'bare'],
#  ['yeah',
#   'go',
#   'stop',
#   'aldi',
#   'home',
#   'hopefully',
#   'food',
#   'leave',
#   'people',
#   'love',
#   'weather',
#   'issue'],
#  ['crossmark',
#   'look',
#   'resourceful',
#   'team',
#   'members',
#   'represent',
#   'clients',
#   'implement',
#   'variety',
#   'store',
#   'merchandise',
#   'activities',
#   'meet',
#   'need',
#   'consumer',
#   'join',
#   'team',
#   'today'],
#  ['look', 'work', 'check'],
#  ['start', 'period', 'know', 'mean', 'publix', 'bakery', 'finna', 'wipe'],
#  ['tempt', 'stop', 'aldi', 'grab', 'things', 'leave', 'office'],
#  ['arkansas',
#   'bout',
#   'money',
#   'great',
#   'athletes',
#   'thank',
#   'rule',
#   'agree',
#   'coach',
#   'smart',
#   'saban',
#   'need',
#   'adjust',
#   'better',
#   'ready',
#   'dump',
#   'money',
#   'hog',
#   'compete',
#   'telon',
#   'say',
#   'bag',
#   'tweet'],
#  ['foods', 'market', 'chicago'],
#  ['biden', 'believe', 'result', 'photo', 'walmart', 'texas', 'week'],
#  ['think', 'pay', 'gallon', 'week', 'costco', 'statio'],
#  ['walmart', 'grocery', 'pickup', 'delivery', 'tempe'],
#  ['bacon', 'lettuce', 'tomato', 'sandwich', 'homemade', 'french', 'bread'],
#  ['look', 'wife', 'ring', 'reward', 'find', 'information', 'help', 'recover'],
#  ['walmart',
#   'know',
#   'walk',
#   'forget',
#   'take',
#   'stuff',
#   'pay',
#   'hope',
#   'good',
#   'karma',
#   'come',
#   'fold',
#   'catch',
#   'camera',
#   'steel',
#   'word',
#   'advice',
#   'shit',
#   'belong'],
#  ['walmart', 'near', 'fort', 'drum', 'near', 'picture', 'take', 'yesterday'],
#  ['supercenter', 'vegas'],
#  ['interest', 'great'],
#  ['hire',
#   'read',
#   'latest',
#   'open',
#   'central',
#   'eastern',
#   'michigan',
#   'inventory',
#   'crew',
#   'member'],
#  ['oversold',
#   'currently',
#   'star',
#   'delay',
#   'order',
#   'wonder',
#   'ship',
#   'say',
#   'months',
#   'unbelievable'],
#  ['hire',
#   'read',
#   'latest',
#   'open',
#   'crossmark',
#   'walmart',
#   'retail',
#   'merchandiser',
#   'time'],
#  ['join', 'meijer', 'team', 'latest', 'open'],
#  ['work', 'stuff', 'costco'],
#  ['recommend'],
#  ['fuck', 'time', 'time', 'wear', 'mask', 'month', 'walmart', 'phone'],
#  ['marcos'],
#  ['differ',
#   'kroger',
#   'say',
#   'mandate',
#   'starbuck',
#   'kiosks',
#   'agree',
#   'think',
#   'businesses',
#   'want',
#   'business',
#   'political',
#   'claim',
#   'kill',
#   'right',
#   'retail',
#   'want',
#   'blame',
#   'exposure',
#   'true'],
#  ['eat',
#   'costco',
#   'truck',
#   'covid',
#   'woman',
#   'drop',
#   'cart',
#   'double',
#   'gloved',
#   'peel',
#   'outer',
#   'ones',
#   'leave',
#   'cart',
#   'clean'],
#  ['want', 'work', 'view', 'latest', 'open'],
#  ['get', 'things', 'include', 'dinner', 'supercenter', 'austintown'],
#  ['visit',
#   'super',
#   'walmart',
#   'kroger',
#   'store',
#   'recently',
#   'stuff',
#   'stock',
#   'huge',
#   'gap',
#   'shelve',
#   'probably',
#   'shortage',
#   'stockers',
#   'problem',
#   'plus',
#   'krogers',
#   'strike',
#   'worst',
#   'shortages',
#   'april',
#   'make',
#   'want',
#   'hoard'],
#  ['think',
#   'things',
#   'normal',
#   'think',
#   'wear',
#   'mask',
#   'hospitals',
#   'urgent',
#   'care',
#   'offices',
#   'walmart'],
#  ['walmart', 'exclusive', 'flavor'],
#  ['forget',
#   'melatonin',
#   'spray',
#   'rush',
#   'walmart',
#   'spray',
#   'lotion',
#   'spray',
#   'time',
#   'kid',
#   'fuck',
#   'go',
#   'trick',
#   'good'],
#  ['real',
#   'customers',
#   'real',
#   'review',
#   'fake',
#   'brand',
#   'ambassadors',
#   'pretend',
#   'like',
#   'products'],
#  ['tanka', 'foods'],
#  ['like',
#   'vocation',
#   'vacation',
#   'help',
#   'good',
#   'folks',
#   'stock',
#   'shelve',
#   'supercenter',
#   'ozark'],
#  ['satisfy', 'produce', 'foods'],
#  ['food', 'court', 'action', 'sunnyvale'],
#  ['feel',
#   'finally',
#   'catch',
#   'post',
#   'video',
#   'awesome',
#   'walk',
#   'walmart',
#   'grab',
#   'mcdonald'],
#  ['want', 'work', 'meijer', 'hire', 'click', 'detail'],
#  ['pull',
#   'shop',
#   'saturday',
#   'nights',
#   'order',
#   'stop',
#   'music',
#   'play',
#   'give',
#   'deal',
#   'favorite',
#   'treat'],
#  ['submit',
#   'quit',
#   'apply',
#   'job',
#   'like',
#   'supervisor',
#   'overnight',
#   'stock',
#   'department',
#   'meijer',
#   'look',
#   'people',
#   'know',
#   'company',
#   'able',
#   'reach',
#   'directly',
#   'ready',
#   'apply',
#   'check',
#   'link'],
#  ['foods', 'market'],
#  ['secure', 'cancel', 'walmart'],
#  ['supercenter', 'ithaca'],
#  ['latest',
#   'click',
#   'apply',
#   'crossmark',
#   'walmart',
#   'retail',
#   'merchandiser',
#   'time'],
#  ['shelve', 'today', 'local', 'publix'],
#  ['hire', 'read', 'latest', 'open', 'cashier'],
#  ['stop', 'shop'],
#  ['cold', 'brew', 'costco', 'bomb'],
#  ['hire',
#   'read',
#   'latest',
#   'open',
#   'general',
#   'merchandise',
#   'stock',
#   'backup',
#   'cashier'],
#  ['spend', 'publix', 'go', 'cereal'],
#  ['time', 'work', 'gotta', 'catch', 'supercenter', 'ellicott', 'city'],
#  ['space',
#   'ship',
#   'bear',
#   'good',
#   'boba',
#   'fett',
#   'film',
#   'call',
#   'shop',
#   'slave',
#   'matter',
#   'stop',
#   'cry'],
#  ['think', 'right', 'costco', 'jesus', 'buy'],
#  ['chance',
#   'board',
#   'stop',
#   'shop',
#   'fitness',
#   'nutrition',
#   'athletes',
#   'adults',
#   'youth',
#   'program',
#   'fitness',
#   'facility',
#   'come',
#   'time',
#   'text'],
#  ['andwhat',
#   'manchin',
#   'care',
#   'family',
#   'rich',
#   'care',
#   'happen',
#   'rest',
#   'nand',
#   'sinnamen',
#   'care',
#   'buy',
#   'continue',
#   'buy',
#   'karma',
#   'visit',
#   'soon'],
#  ['cutest', 'come', 'middle', 'kroger', 'go', 'look', 'like', 'like', 'wear'],
#  ['walmart', 'bakery', 'wimauma'],
#  ['costco',
#   'valentines',
#   'flower',
#   'chocolate',
#   'cover',
#   'strawberries',
#   'nbest'],
#  ['lang',
#   'traders',
#   'abram',
#   'stop',
#   'shop',
#   'martial',
#   'arts',
#   'supply',
#   'city',
#   'arlington',
#   'listen',
#   'downtown'],
#  ['favorite',
#   'unhinge',
#   'food',
#   'lion',
#   'fayetteville',
#   'nccu',
#   'shit',
#   'see',
#   'store',
#   'time',
#   'mayor',
#   'say',
#   'like',
#   'sneakers',
#   'extra',
#   'point'],
#  ['recommend'],
#  ['saturday', 'sunday', 'costco', 'cheaper', 'regular', 'station'],
#  ['look',
#   'assistance',
#   'sponsorship',
#   'acquisition',
#   'career',
#   'path',
#   'management',
#   'public',
#   'relations',
#   'design',
#   'market',
#   'stop',
#   'shop',
#   'manage',
#   'business',
#   'motorsports',
#   'nemail',
#   'today',
#   'info'],
#  ['join',
#   'crossmark',
#   'team',
#   'latest',
#   'retail',
#   'merchandise',
#   'open',
#   'include',
#   'crossmark',
#   'walmart',
#   'retail',
#   'merchandiser',
#   'time',
#   'link'],
#  ['squirrel', 'food', 'holt'],
#  ['goal', 'learn', 'cook', 'entree', 'dish', 'dessert', 'costco', 'club'],
#  ['beat', 'walmart', 'gift', 'card', 'sweepstakes'],
#  ['pause', 'rhom', 'publix'],
#  ['grandson',
#   'latrax',
#   'prerunner',
#   'learn',
#   'drive',
#   'body',
#   'destroy',
#   'cheap',
#   'walmart',
#   'hard',
#   'body',
#   'perfectly'],
#  ['publix', 'loxahatchee', 'groves'],
#  ['buy',
#   'plan',
#   'buy',
#   'father',
#   'semi',
#   'walmart',
#   'dale',
#   'earnhardt',
#   'decals'],
#  ['walmart', 'personal', 'goin', 'crazy'],
#  ['join', 'meijer', 'team', 'latest', 'open'],
#  ['work', 'product', 'placement', 'walmart', 'today'],
#  ['piece', 'people', 'push', 'debunk', 'desantis', 'publix', 'hoax'],
#  ['fema',
#   'disaster',
#   'recovery',
#   'center',
#   'offer',
#   'stop',
#   'shop',
#   'tornado',
#   'survivors',
#   'help'],
#  ['downfromthesky', 'call', 'form'],
#  ['costco',
#   'tulsa',
#   'oklahoma',
#   'freeze',
#   'pepperoni',
#   'pizza',
#   'girlfriend',
#   'nausea',
#   'begin',
#   'food',
#   'poison'],
#  ['photos',
#   'super',
#   'mario',
#   'nabbit',
#   'figure',
#   'nthis',
#   'figure',
#   'currently',
#   'hit',
#   'checkout',
#   'lanes'],
#  ['downfromthesky',
#   'hope',
#   'pay',
#   'tax',
#   'report',
#   'gross',
#   'sales',
#   'facebook',
#   'ebay',
#   'auto',
#   'report',
#   'info',
#   'mess',
#   'stricter'],
#  ['holt', 'shit', 'shelve', 'bare', 'meijer', 'lansing'],
#  ['kroger',
#   'marie',
#   'callender',
#   'macon',
#   'georgia',
#   'buy',
#   'marie',
#   'callender',
#   'buffalo',
#   'style',
#   'cheese',
#   'freeze',
#   'meal',
#   'night',
#   'food',
#   'poison'],
#  ['mark',
#   'bizzelle',
#   'paycheck',
#   'entainment',
#   'charles',
#   'schwab',
#   'industrial',
#   'valley',
#   'bank',
#   'budget',
#   'authorize',
#   'walmart'],
#  ['costco', 'pack'],
#  ['cool', 'walmart', 'go', 'yogurt'],
#  ['hafta',
#   'throw',
#   'jacket',
#   'cover',
#   'cold',
#   'temp',
#   'indicators',
#   'horn',
#   'walk',
#   'walmart',
#   'get',
#   'stop',
#   'security',
#   'hide',
#   'kielbasa',
#   'jeans',
#   'think'],
#  ['production', 'underway', 'shoot', 'clutch', 'driver'],
#  ['costco', 'animal', 'crackers', 'healthy', 'diet'],
#  ['mark',
#   'bizzelle',
#   'paycheck',
#   'entainment',
#   'charles',
#   'schwab',
#   'industrial',
#   'valley',
#   'bank',
#   'budget',
#   'walmart',
#   'urgent',
#   'care',
#   'center',
#   'business',
#   'skype'],
#  ['grate',
#   'gruyere',
#   'cheese',
#   'publix',
#   'inspire',
#   'french',
#   'onion',
#   'soup',
#   'crockpot',
#   'overnight'],
#  ['crave', 'cereal', 'pump', 'publix'],
#  ['notice', 'increase', 'especially', 'publix', 'touristy', 'area'],
#  ['dark',
#   'chocolates',
#   'jam',
#   'spice',
#   'honey',
#   'assort',
#   'crisp',
#   'fresh',
#   'berry',
#   'kudos',
#   'blackberry',
#   'underrate',
#   'misunderstand',
#   'berry',
#   'enjoy',
#   'sweet',
#   'pepper',
#   'spreadable',
#   'cheez',
#   'goat',
#   'cheez',
#   'aldi',
#   'cheer',
#   'bengals'],
#  ['rouse', 'walmart'],
#  ['truly', 'pleasure', 'shop', 'work', 'cute'],
#  ['mark',
#   'bizzelle',
#   'paycheck',
#   'entainment',
#   'charles',
#   'schwab',
#   'industrial',
#   'valley',
#   'bank',
#   'budget',
#   'mcdonald',
#   'best',
#   'dollar',
#   'tree',
#   'family',
#   'dollar',
#   'greyhound',
#   'mega',
#   'deli',
#   'own',
#   'microsoft',
#   'business',
#   'skype',
#   'walgreen',
#   'pharmcy',
#   'walmart'],
#  ['nout',
#   'curiosity',
#   'boycott',
#   'nike',
#   'oreo',
#   'cookies',
#   'walmart',
#   'netflix',
#   'budweiser',
#   'starbucks',
#   'keurig',
#   'target',
#   'pepsi',
#   'gillette',
#   'nordstrom',
#   'univision',
#   'watch',
#   'stuff'],
#  ['visit', 'florida', 'walmart', 'disappoint'],
#  ['latest',
#   'opportunity',
#   'click',
#   'link',
#   'apply',
#   'application',
#   'security',
#   'engineer',
#   'meijer'],
#  ['join', 'meijer', 'team', 'latest', 'open'],
# ...
#  ['thank',
#   'guy',
#   'love',
#   'blts',
#   'post',
#   'food',
#   'picture',
#   'daily',
#   'haven',
#   'months',
#   'days',
#   'months',
#   'rest',
#   'feel',
#   'better'],
#  ['thank', 'pick', 'bacon', 'tomatoes', 'lettuce', 'guy', 'love', 'blts'],
#  ['post',
#   'try',
#   'need',
#   'sister',
#   'bread',
#   'drop',
#   'blood',
#   'draw',
#   'vlad',
#   'need',
#   'blood',
#   'today'],
#  ['crossmark',
#   'hire',
#   'miami',
#   'read',
#   'latest',
#   'retail',
#   'merchandise',
#   'open',
#   'link',
#   'crossmark',
#   'walmart',
#   'retail',
#   'merchandiser',
#   'time',
#   'reader',
#   'link'],
#  ['nervous',
#   'apply',
#   'like',
#   'fleet',
#   'mechanic',
#   'meijer',
#   'apply',
#   'match',
#   'underestimate',
#   'value',
#   'click',
#   'link',
#   'info'],
#  ['days', 'production', 'days', 'driver'],
#  ['sweet',
#   'cashier',
#   'keep',
#   'look',
#   'hoodie',
#   'tell',
#   'like',
#   'hoodie',
#   'tell',
#   'meijer'],
#  ['join', 'meijer', 'team', 'latest', 'open'],
#  ['viking',
#   'glorify',
#   'looters',
#   'cause',
#   'pain',
#   'modern',
#   'walmart',
#   'shoppers',
#   'opportunity',
#   'present',
#   'thugs',
#   'thugs',
#   'history',
#   'want',
#   'will',
#   'work',
#   'trend',
#   'start',
#   'lately'],
#  ['humboldt', 'creamery', 'vanilla', 'cream', 'love', 'house'],
#  ['spread',
#   'prepare',
#   'legalese',
#   'seat',
#   'try',
#   'courthouse',
#   'post',
#   'office',
#   'foods'],
#  ['paul',
#   'kroger',
#   'vine',
#   'village',
#   'roll',
#   'lift',
#   'truck',
#   'happy',
#   'healthy',
#   'perfectly',
#   'good',
#   'rescue',
#   'food',
#   'fee',
#   'hungry',
#   'people',
#   'community'],
#  ['pass', 'aldi', 'plant', 'intel', 'scoop'],
#  ['metaverse', 'online', 'virtual', 'world', 'nmom', 'walmart', 'join'],
#  ['look',
#   'score',
#   'meijer',
#   'luck',
#   'click',
#   'link',
#   'description',
#   'information',
#   'apply',
#   'cashier'],
#  ['fairfax'],
#  ['post', 'photo', 'walmart'],
#  ['costco', 'blood'],
#  ['want', 'work', 'meijer', 'hire', 'click', 'detail'],
#  ['good', 'morning', 'foods', 'market'],
#  ['sub', 'wish', 'know', 'outstanding', 'food'],
#  ['story', 'moms', 'read', 'hear'],
#  ['foods', 'manhattan', 'january', 'foods', 'market'],
#  ['foods', 'manhattan', 'january'],
#  ['jackson',
#   'stop',
#   'lie',
#   'american',
#   'people',
#   'want',
#   'store',
#   'live',
#   'shop'],
#  ['save',
#   'money',
#   'walmart',
#   'know',
#   'target',
#   'give',
#   'discount',
#   'debit',
#   'card'],
#  ['foods', 'buffalo', 'orchard', 'park', 'drive', 'amherst'],
#  ['pete',
#   'meijer',
#   'fuck',
#   'smart',
#   'know',
#   'nand',
#   'vote',
#   'complicit',
#   'despite',
#   'reasonable',
#   'bullshit',
#   'persona'],
#  ['join', 'crossmark', 'team', 'latest', 'open'],
#  ['yeah', 'walmart', 'supremacy'],
#  ['publix',
#   'sawgrass',
#   'area',
#   'people',
#   'inside',
#   'immediately',
#   'talk',
#   'microphone',
#   'louder',
#   'woman',
#   'cells',
#   'phone',
#   'follow',
#   'store',
#   'bank',
#   'malls',
#   'esta',
#   'gente',
#   'ganan',
#   'dinero',
#   'acosar',
#   'otros'],
#  ['walmart',
#   'flowood',
#   'mississippi',
#   'yesterday',
#   'blueberry',
#   'sausage',
#   'people',
#   'symptoms',
#   'start',
#   'hours',
#   'consumpt',
#   'food',
#   'poison'],
#  ['dallas'],
#  ['costco',
#   'kirkland',
#   'signature',
#   'florence',
#   'kentucky',
#   'daughter',
#   'purchase',
#   'lasagna',
#   'food',
#   'poison'],
#  ['time',
#   'taquitos',
#   'exactly',
#   'count',
#   'glance',
#   'provide',
#   'guacamole',
#   'sour',
#   'cream',
#   'sociopathic',
#   'behavior',
#   'people'],
#  ['walmart', 'apollo', 'walmart'],
#  ['jimmy',
#   'dean',
#   'kroger',
#   'dallas',
#   'texas',
#   'tuesday',
#   'today',
#   'finish',
#   'jimmy',
#   'deans',
#   'eggwich',
#   'come',
#   'food',
#   'poison'],
#  ['walmart',
#   'marketside',
#   'urbana',
#   'ohio',
#   'purchase',
#   'marketside',
#   'premium',
#   'romaine',
#   'salad',
#   'arou',
#   'food',
#   'poison'],
#  ['perfect',
#   'sponsor',
#   'civil',
#   'right',
#   'museum',
#   'build',
#   'african',
#   'american',
#   'museum',
#   'work',
#   'tell',
#   'real',
#   'story',
#   'know',
#   'tell',
#   'truth',
#   'partner',
#   'museum'],
#  ['work', 'walmart'],
#  ['understand',
#   'store',
#   'walmart',
#   'target',
#   'stay',
#   'open',
#   'small',
#   'place',
#   'couldn',
#   'virus',
#   'attack',
#   'small',
#   'store'],
#  ['snow',
#   'missouri',
#   'people',
#   'start',
#   'doomsday',
#   'prepping',
#   'local',
#   'walmart'],
#  ['place', 'like', 'costco'],
#  ['kroger', 'king'],
#  ['order',
#   'walmart',
#   'connect',
#   'canada',
#   'india',
#   'item',
#   'money',
#   'order',
#   'shop',
#   'walmart'],
#  ['order', 'walmart', 'connect', 'canada', 'india', 'item', 'money'],
#  ['lactaid', 'lactose', 'free', 'vitamin', 'milk'],
#  ['stray',
#   'puppy',
#   'stomp',
#   'death',
#   'consume',
#   'body',
#   'gulp',
#   'unlatching',
#   'like',
#   'sort',
#   'reptile'],
#  ['case',
#   'afford',
#   'visit',
#   'australia',
#   'talk',
#   'farthest',
#   'place',
#   'people',
#   'local',
#   'walmart',
#   'local',
#   'mental',
#   'institution',
#   'case'],
#  ['anybody',
#   'say',
#   'desirable',
#   'apartment',
#   'local',
#   'walmart',
#   'live',
#   'dairy',
#   'cooler'],
#  ['call', 'publix', 'boycott'],
#  ['call', 'walmart', 'grocery', 'shop', 'tell'],
#  ['yesterday', 'today', 'blat'],
#  ['see', 'kroger', 'like', 'chill', 'mama'],
#  ['imagine', 'treat', 'underpay', 'employees'],
#  ['walmart', 'true', 'embodiment', 'american', 'psyche'],
#  ['couple', 'costco', 'stay'],
#  ['enjoy',
#   'surf',
#   'turf',
#   'watch',
#   'game',
#   'brother',
#   'ask',
#   'buy',
#   'lobster',
#   'tail',
#   'gilbert',
#   'say',
#   'dinner',
#   'costco',
#   'say',
#   'onions'],
#  ['simple',
#   'quick',
#   'costco',
#   'dinner',
#   'nlove',
#   'grateful',
#   'mountlake',
#   'terrace',
#   'washington'],
#  ['thank'],
#  ['course', 'bring', 'chicken', 'tender'],
#  ['shesnicety', 'lawd', 'anymore', 'walmart', 'better', 'come'],
#  ['line',
#   'self',
#   'checkout',
#   'lane',
#   'open',
#   'cashier',
#   'rest',
#   'self',
#   'checkout',
#   'trop',
#   'jones',
#   'guess',
#   'want',
#   'employee',
#   'check',
#   'folks',
#   'check',
#   'employees',
#   'right'],
#  ['need', 'publix', 'chicken'],
#  ['damn', 'feel', 'like', 'go', 'walmart'],
#  ['bacon', 'lettuce', 'tomato', 'sandwich', 'homemade', 'french', 'bread'],
#  ['love', 'foods'],
#  ['note', 'photos', 'take', 'walmart'],
#  ['eat', 'foods', 'drop', 'grace'],
#  ['rent', 'struggle', 'plush', 'aldi', 'today', 'score', 'time'],
#  ['throw', 'aware', 'home', 'kit', 'stock', 'stock'],
#  ['local',
#   'kroger',
#   'stock',
#   'make',
#   'feel',
#   'like',
#   'society',
#   'finna',
#   'collapse'],
#  ['weak', 'right', 'weak', 'black', 'person', 'call', 'aldis', 'aldi'],
#  ['want',
#   'nice',
#   'juicy',
#   'steak',
#   'breakfast',
#   'tomorrow',
#   'harris',
#   'teeter',
#   'publix',
#   'gotta'],
#  ['plain',
#   'pickle',
#   'garlic',
#   'sherry',
#   'balsamic',
#   'vinegar',
#   'nbut',
#   'successfully',
#   'buy',
#   'feel',
#   'like',
#   'costco',
#   'entire',
#   'inventory',
#   'pickle',
#   'prepping',
#   'stuff',
#   'fridge',
#   'pantry'],
#  ['haha',
#   'referendums',
#   'couldn',
#   'wine',
#   'grocery',
#   'store',
#   'state',
#   'week',
#   'nthat',
#   'chattanooga',
#   'costco',
#   'yards',
#   'state',
#   'line',
#   'catoosa',
#   'county'],
#  ['walmart', 'halloween', 'costume', 'scent', 'candle'],
#  ['amaze',
#   'product',
#   'beef',
#   'shank',
#   'amaze',
#   'team',
#   'riverside',
#   'illinois'],
#  ['awesome', 'cincinnati'],
#  ['nan'],
#  ['need', 'involve', 'wife', 'mckenzie', 'bail', 'best'],
#  ['sure', 'brand', 'costco'],
#  ['walmart', 'sweat'],
#  ['food', 'shop', 'hungry', 'stop', 'shop'],
#  ['kroger', 'check', 'haven', 'know', 'good', 'stuff'],
#  ['buy',
#   'toilet',
#   'paper',
#   'egg',
#   'fork',
#   'covid',
#   'time',
#   'baybeeeeee',
#   'kickflipping',
#   'costco'],
#  ['walmart'],
#  ['thankful',
#   'local',
#   'community',
#   'pendleton',
#   'walmart',
#   'amaze',
#   'donations',
#   'shelter',
#   'animals',
#   'love'],
#  ['impose',
#   'tariff',
#   'goods',
#   'come',
#   'mainland',
#   'china',
#   'sell',
#   'american',
#   'corporations',
#   'large',
#   'retailers',
#   'amazon',
#   'walmart',
#   'target'],
#  ['walmart', 'target'],
#  ['good'],
#  ['ironically',
#   'prove',
#   'useful',
#   'medication',
#   'printout',
#   'target',
#   'incorrect',
#   'list',
#   'medication',
#   'know',
#   'buy',
#   'costco',
#   'instead',
#   'catch',
#   'costco',
#   'stop',
#   'best',
#   'headquarter',
#   'minneapolis',
#   'irony'],
#  ['meijer',
#   'look',
#   'teammates',
#   'like',
#   'latest',
#   'open',
#   'include',
#   'facilities',
#   'maintenance',
#   'mechanic',
#   'link'],
#  ['little', 'outdoors', 'therapy', 'ribeyes', 'costco', 'cheese'],
#  ['walmart', 'cool', 'ones', 'nfocus', 'favorite'],
#  ['costco'],
#  ['stop', 'shop'],
#  ['work',
#   'kroger',
#   'socal',
#   'divisions',
#   'state',
#   'dunno',
#   'keep',
#   'tech',
#   'computers'],
#  ['costco', 'stop', 'lie'],
#  ['diego'],
#  ['play', 'gettin', 'jiggy', 'walmart', 'vibing'],
#  ['walmart',
#   'tigard',
#   'oregon',
#   'bacon',
#   'think',
#   'consume',
#   'bacon',
#   'year',
#   'throw',
#   'bacon',
#   'food',
#   'poison'],
#  ['see',
#   'profound',
#   'shit',
#   'din',
#   'room',
#   'table',
#   'giant',
#   'melon',
#   'sit',
#   'table',
#   'right',
#   'nice',
#   'wood',
#   'glass',
#   'display',
#   'container',
#   'inside',
#   'container',
#   'keep',
#   'fresh',
#   'instead',
#   'melon',
#   'costco',
#   'reward',
#   'card',
#   'damn',
#   'nothin'],
#  ['city',
#   'market',
#   'grand',
#   'junction',
#   'colorado',
#   'meal',
#   'kroger',
#   'brand',
#   'grape',
#   'tomatoes',
#   'throw',
#   'food',
#   'poison'],
#  ['foods', 'market', 'edina'],
#  ['dangerous',
#   'rhetoric',
#   'absolutely',
#   'false',
#   'inflammatory',
#   'stir',
#   'racial',
#   'resentment',
#   'need',
#   'paso',
#   'walmart',
#   'massacre',
#   'unstable',
#   'individual',
#   'easy',
#   'access',
#   'firearms',
#   'radicalize',
#   'false',
#   'narrative',
#   'report'],
#  ['want', 'work', 'view', 'latest', 'open'],
#  ['kroger', 'sushi', 'good'],
#  ['go', 'walmart', 'forget', 'grab', 'cheesecake', 'lmao', 'stupes', 'omgggg'],
#  ['freshly', 'slice', 'italian', 'bread', 'hearth', 'bread'],
#  ['thank', 'go', 'check', 'costco'],
#  ['think', 'safe', 'longer', 'fringe', 'industry'],
#  ['incognito', 'mode', 'walmart', 'staunton'],
#  ['russell',
#   'westbrook',
#   'get',
#   'triple',
#   'lucky',
#   'follower',
#   'reward',
#   'walmart',
#   'gift',
#   'card',
#   'follow',
#   'comment'],
#  ['walmart', 'crypto', 'nfts'],
#  ['look',
#   'score',
#   'meijer',
#   'luck',
#   'click',
#   'link',
#   'description',
#   'information',
#   'apply',
#   'store',
#   'inventory',
#   'crew',
#   'member'],
#  ['reason', 'know', 'kentucky', 'local', 'ohio', 'kroger'],
#  ['walmart', 'cranston', 'lmao'],
#  ['foods', 'market', 'clark'],
#  ['leave', 'stop', 'shop', 'fully', 'stock'],
#  ['want', 'work', 'meijer', 'hire', 'click', 'detail'],
#  ['shoot',
#   'tesla',
#   'driver',
#   'park',
#   'pickup',
#   'spot',
#   'go',
#   'inside',
#   'shop'],
#  ['fwiw',
#   'costco',
#   'carry',
#   'usable',
#   'small',
#   'households',
#   'products',
#   'purchase',
#   'executive',
#   'membership'],
#  ['place',
#   'like',
#   'frills',
#   'publix',
#   'kroger',
#   'plus',
#   'foods',
#   'cheaper',
#   'fiesta',
#   'cheap'],
#  ['tax', 'walmart', 'mcdonalds'],
#  ['know',
#   'know',
#   'stuff',
#   'amaze',
#   'able',
#   'foods',
#   'carmel',
#   'know',
#   'source',
#   'central',
#   'indiana',
#   'fishers',
#   'indiana'],
#  ['walmart', 'home', 'test', 'area', 'walmart', 'landover', 'hill', 'plenty'],
#  ['foods', 'market', 'santa', 'clara'],
#  ['hire',
#   'read',
#   'latest',
#   'open',
#   'human',
#   'resources',
#   'representative',
#   'springfield'],
#  ['tear', 'walmart', 'bathroom'],
#  ['people',
#   'government',
#   'stock',
#   'make',
#   'purchase',
#   'grocery',
#   'store',
#   'government',
#   'run',
#   'walmart',
#   'safeway',
#   'target',
#   'food',
#   'lion',
#   'target',
#   'trader',
#   'hyvee',
#   'costco'],
#  ['explain', 'think', 'process', 'decide', 'price', 'bake', 'goods'],
#  ['lithia'],
#  ['great', 'vibes', 'costco', 'right'],
#  ['home', 'depot', 'nwalmart', 'nferreteria', 'national', 'calle', 'post'],
#  ['pharmacy', 'austin'],
#  ['supercenter', 'austin'],
#  ['date', 'fred', 'meyer', 'kroger'],
#  ['fave',
#   'emerge',
#   'florida',
#   'artists',
#   'nseason',
#   'feature',
#   'florida',
#   'bear',
#   'raise',
#   'singer',
#   'songwriter',
#   'play',
#   'elliot',
#   'nstop',
#   'shop',
#   'pick',
#   'debut',
#   'official',
#   'album',
#   'forget',
#   'demo',
#   'wcpgw',
#   'supply'],
#  ['recommend'],
#  ['fuck',
#   'walmart',
#   'order',
#   'mast',
#   'cell',
#   'stabilizers',
#   'fever',
#   'reducers',
#   'free',
#   'post'],
#  ['super', 'market', 'gateway', 'village', 'clemson'],
#  ['members',
#   'ufcw',
#   'chant',
#   'respect',
#   'protect',
#   'essential',
#   'workers',
#   'outside',
#   'harvard',
#   'square',
#   'own'],
#  ['want',
#   'help',
#   'save',
#   'environment',
#   'quit',
#   'buy',
#   'products',
#   'build',
#   'fail',
#   'immediately'],
#  ['gonna', 'park', 'costco', 'sleepy'],
#  ['park', 'walmart', 'store', 'ride', 'mins', 'look', 'close', 'spot'],
#  ['right', 'time', 'compliment', 'walmart'],
#  ['encounter',
#   'walmart',
#   'earlier',
#   'today',
#   'elderly',
#   'black',
#   'come',
#   'say',
#   'look',
#   'like',
#   'throw',
#   'weight',
#   'look',
#   'arm',
#   'like',
#   'shoulder',
#   'little',
#   'things',
#   'like',
#   'go'],
#  ['walmart',
#   'issue',
#   'want',
#   'work',
#   'want',
#   'minimum',
#   'wage',
#   'work',
#   'master',
#   'degree'],
#  ['sense',
#   'urgency',
#   'shouldn',
#   'difficult',
#   'food',
#   'check',
#   'status',
#   'shoutout',
#   'rude',
#   'manager',
#   'rosemead',
#   'store',
#   'options'],
#  ['interest', 'great'],
#  ['walmart', 'clearance', 'providence', 'rhode', 'island'],
#  ['stop', 'shop', 'star', 'market', 'roche', 'bros', 'order', 'anymore'],
#  ['inspire', 'walmart', 'walmart'],
#  ['post', 'photo', 'walmart', 'supercenter', 'saugus'],
#  ['commack'],
#  ['best',
#   'salad',
#   'idgaf',
#   'worth',
#   'aldi',
#   'ingredient',
#   'salads',
#   'weeks',
#   'totally',
#   'worth'],
#  ['want', 'work', 'meijer', 'hire', 'click', 'detail'],
#  ['sheeps',
#   'milk',
#   'cheese',
#   'manchego',
#   'cheddar',
#   'great',
#   'local',
#   'feta',
#   'good'],
#  ['today', 'foods', 'market'],
#  ['foods',
#   'insistence',
#   'have',
#   'cashier',
#   'matter',
#   'people',
#   'store',
#   'inspire',
#   'champ'],
#  ['walmart',
#   'join',
#   'metaverse',
#   'mean',
#   'start',
#   'see',
#   'crypto',
#   'voxel',
#   'pajamas'],
#  ['imagine',
#   'novue',
#   'riche',
#   'billionaires',
#   'china',
#   'market',
#   'like',
#   'walmart'],
#  ['dallas'],
#  ['hire', 'read', 'latest', 'open', 'shift', 'stock', 'rate'],
#  ['food', 'shop', 'shelve', 'get', 'bare', 'stuff'],
#  ['nget', 'good'],
#  ['america',
#   'justice',
#   'society',
#   'thomas',
#   'rafael',
#   'kayanan',
#   'mike',
#   'hernandez',
#   'alfredo',
#   'alcala',
#   'foods',
#   'market'],
#  ['pete',
#   'wrong',
#   'beach',
#   'store',
#   'shelve',
#   'kroger',
#   'trader',
#   'joes',
#   'stock',
#   'products',
#   'place',
#   'items',
#   'walmart',
#   'harris',
#   'teter',
#   'walmart',
#   'ship',
#   'worsen',
#   'china',
#   'close',
#   'port'],
#  ['owner',
#   'warriors',
#   'own',
#   'approximately',
#   'team',
#   'guess',
#   'stockholder',
#   'costco',
#   'owner'],
#  ['sound', 'like', 'shoulda', 'walmart'],
#  ['woah'],
#  ['tell', 'lemon', 'juice', 'substitute', 'lime', 'juice', 'pickup', 'order'],
#  ['walmart', 'completely', 'outta', 'cream', 'bunch'],
#  ['walmart', 'example', 'destroy', 'store'],
#  ['recommend',
#   'click',
#   'link',
#   'south',
#   'cincinnati',
#   'inventory',
#   'crew',
#   'member',
#   'meijer'],
#  ['time', 'true', 'memory', 'foam', 'slip', 'slide', 'feel', 'good', 'better'],
#  ['want', 'work', 'view', 'latest', 'open'],
#  ['clear', 'refer', 'giant', 'eagle'],
#  ['walmart', 'break', 'street', 'date', 'saturday'],
#  ['look', 'work', 'check'],
#  ['long', 'island', 'city'],
#  ['buy',
#   'years',
#   'costco',
#   'time',
#   'good',
#   'deal',
#   'unit',
#   'love',
#   'come',
#   'best'],
#  ['walmart', 'anne', 'njust', 'walmart'],
#  ['louisville',
#   'khsaa',
#   'football',
#   'years',
#   'go',
#   'kroger',
#   'freedom',
#   'hall',
#   'host',
#   'sweet',
#   'years',
#   'stink',
#   'opinion',
#   'know',
#   'lot',
#   'folks',
#   'state',
#   'majority',
#   'want',
#   'tournaments',
#   'louisville'],
#  ['love', 'walmart'],
#  ['time',
#   'true',
#   'warm',
#   'slip',
#   'slide',
#   'run',
#   'grocery',
#   'store',
#   'simply',
#   'take',
#   'trash',
#   'curb',
#   'warm',
#   'comfy',
#   'kick',
#   'cool',
#   'available',
#   'black',
#   'camouflage',
#   'green'],
#  ['take', 'walmart', 'justice', 'toy', 'clothe'],
#  ['walk', 'walmart', 'open', 'busch', 'light', 'chest', 'pocket', 'overalls'],
#  ['reason', 'go', 'walmart'],
#  ['solve', 'costco', 'bigger', 'cheaper', 'win', 'nalso', 'work'],
#  ...]

# %%
# %%time

# Train STTM model
# Init of the Gibbs Sampling Dirichlet Mixture Model algorithm
# K = number of potential topic (which we don't know a priori)
# alpha = 
# beta = 
# n_iters = number of iterations to 
mgp = MovieGroupProcess(K=8, alpha=0.1, beta=0.1, n_iters=40)
vocab = set(x for doc in docs for x in doc)
n_terms = len(vocab)
y = mgp.fit(docs, n_terms)
# Out:
# In stage 0: transferred 107346 clusters with 8 clusters populated
# In stage 1: transferred 87506 clusters with 8 clusters populated
# In stage 2: transferred 73505 clusters with 8 clusters populated
# In stage 3: transferred 61571 clusters with 8 clusters populated
# In stage 4: transferred 53086 clusters with 8 clusters populated
# In stage 5: transferred 47367 clusters with 8 clusters populated
# In stage 6: transferred 43344 clusters with 8 clusters populated
# In stage 7: transferred 40994 clusters with 8 clusters populated
# In stage 8: transferred 39529 clusters with 8 clusters populated
# In stage 9: transferred 38092 clusters with 8 clusters populated
# In stage 10: transferred 37119 clusters with 8 clusters populated
# In stage 11: transferred 36284 clusters with 8 clusters populated
# In stage 12: transferred 35752 clusters with 8 clusters populated
# In stage 13: transferred 35608 clusters with 8 clusters populated
# In stage 14: transferred 35382 clusters with 8 clusters populated
# In stage 15: transferred 35318 clusters with 8 clusters populated
# In stage 16: transferred 35009 clusters with 8 clusters populated
# In stage 17: transferred 34884 clusters with 8 clusters populated
# In stage 18: transferred 34840 clusters with 8 clusters populated
# In stage 19: transferred 34763 clusters with 8 clusters populated
# In stage 20: transferred 34624 clusters with 8 clusters populated
# In stage 21: transferred 34449 clusters with 8 clusters populated
# In stage 22: transferred 34236 clusters with 8 clusters populated
# In stage 23: transferred 34086 clusters with 8 clusters populated
# In stage 24: transferred 34133 clusters with 8 clusters populated
# In stage 25: transferred 34184 clusters with 8 clusters populated
# In stage 26: transferred 34267 clusters with 8 clusters populated
# In stage 27: transferred 34011 clusters with 8 clusters populated
# In stage 28: transferred 34284 clusters with 8 clusters populated
# In stage 29: transferred 34136 clusters with 8 clusters populated
# In stage 30: transferred 33950 clusters with 8 clusters populated
# In stage 31: transferred 33895 clusters with 8 clusters populated
# In stage 32: transferred 33861 clusters with 8 clusters populated
# In stage 33: transferred 33801 clusters with 8 clusters populated
# In stage 34: transferred 33584 clusters with 8 clusters populated
# In stage 35: transferred 33567 clusters with 8 clusters populated
# In stage 36: transferred 33513 clusters with 8 clusters populated
# In stage 37: transferred 33234 clusters with 8 clusters populated
# In stage 38: transferred 33186 clusters with 8 clusters populated
# In stage 39: transferred 33144 clusters with 8 clusters populated
# Wall time: 16min 43s

# %%
# Save model
with open(r'E:\OneDrive - University of Georgia\Project\Script\5.0 TopicModeling\dumps\trained_models\8clusters_2021.model', 'wb') as f:
    pickle.dump(mgp, f)
    f.close()

# %%
# Load in trained model with 10 topics 
filehandler = open(r'E:\OneDrive - University of Georgia\Project\Script\5.0 TopicModeling\dumps\trained_models\8clusters_2021.model', 'rb')
mgp = pickle.load(filehandler)

# %%
# Helper function
def top_words(cluster_word_distribution, top_cluster, values):
    '''prints the top words in each cluster'''
    for cluster in top_cluster:
        sort_dicts =sorted(mgp.cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print('Cluster %s : %s'%(cluster,sort_dicts))
        print(' — — — — — — — — —')

# %%
doc_count = np.array(mgp.cluster_doc_count)
print('Number of documents per topic :', doc_count)
print('*'*20)

# Topics sorted by the number of document they are allocated to
top_index = doc_count.argsort()[-10:][::-1]
print('Most important clusters (by number of docs inside):', top_index)
print('*'*20)

# Show the top 5 words in term frequency for each cluster 
topic_indices = np.arange(start=0, stop=len(doc_count), step=1)
top_words(mgp.cluster_word_distribution, topic_indices, 20)
# Out:
# Number of documents per topic : [22394  7480 25212 14845  9379 10778 33327  6575]
# ********************
# Most important clusters (by number of docs inside): [6 2 0 3 5 4 1 7]
# ********************
# Cluster 0 : [('costco', 6618), ('foods', 3593), ('walmart', 2818), ('publix', 2574), ('like', 1904), ('kroger', 1730), ('aldi', 1551), ('go', 1352), ('good', 1346), ('chicken', 1324), ('food', 1239), ('buy', 1016), ('love', 866), ('need', 829), ('shop', 820), ('store', 809), ('today', 796), ('time', 786), ('sell', 781), ('pizza', 771)]
#  — — — — — — — — —
# Cluster 1 : [('walmart', 2577), ('publix', 1054), ('kroger', 1015), ('vaccine', 936), ('shoot', 929), ('covid', 770), ('store', 475), ('costco', 433), ('appointment', 430), ('appointments', 416), ('people', 391), ('today', 387), ('go', 366), ('available', 362), ('thank', 353), ('park', 328), ('shop', 325), ('stop', 284), ('time', 282), ('open', 272)]
#  — — — — — — — — —
# Cluster 2 : [('walmart', 11122), ('costco', 5516), ('store', 2194), ('go', 2072), ('like', 1935), ('order', 1877), ('time', 1761), ('shop', 1618), ('need', 1600), ('card', 1398), ('kroger', 1339), ('work', 1248), ('line', 1177), ('know', 1176), ('people', 1153), ('today', 1108), ('wait', 1059), ('come', 1031), ('check', 1026), ('think', 1017)]
#  — — — — — — — — —
# Cluster 3 : [('walmart', 5323), ('mask', 1904), ('people', 1743), ('publix', 1739), ('store', 1626), ('costco', 1611), ('like', 1326), ('shop', 1264), ('kroger', 1210), ('work', 1112), ('employees', 976), ('go', 899), ('know', 889), ('wear', 864), ('need', 775), ('company', 757), ('think', 755), ('stop', 716), ('foods', 712), ('time', 640)]
#  — — — — — — — — —
# Cluster 4 : [('supercenter', 2868), ('walmart', 2324), ('food', 1689), ('poison', 1270), ('publix', 534), ('nan', 518), ('kroger', 436), ('city', 419), ('costco', 390), ('meijer', 373), ('pharmacy', 372), ('grocery', 343), ('morning', 310), ('good', 305), ('pickup', 269), ('sick', 265), ('rock', 265), ('center', 260), ('little', 257), ('henderson', 256)]
#  — — — — — — — — —
# Cluster 5 : [('shop', 4288), ('stop', 3793), ('walmart', 2081), ('today', 1083), ('open', 1054), ('thank', 783), ('work', 536), ('come', 530), ('store', 509), ('great', 499), ('meijer', 490), ('want', 478), ('kroger', 475), ('gift', 457), ('latest', 444), ('team', 440), ('time', 423), ('need', 401), ('costco', 391), ('local', 371)]
#  — — — — — — — — —
# Cluster 6 : [('walmart', 19694), ('like', 4327), ('costco', 4065), ('go', 3367), ('kroger', 2016), ('look', 1852), ('shop', 1736), ('work', 1592), ('know', 1590), ('time', 1587), ('walk', 1564), ('publix', 1509), ('today', 1498), ('park', 1473), ('people', 1449), ('need', 1384), ('foods', 1383), ('say', 1376), ('think', 1359), ('come', 1301)]
#  — — — — — — — — —
# Cluster 7 : [('walmart', 2055), ('post', 1766), ('photo', 1639), ('costco', 1558), ('market', 1238), ('foods', 846), ('gasoline', 668), ('supercenter', 364), ('neighborhood', 346), ('heights', 206), ('publix', 204), ('shop', 198), ('wholesale', 196), ('super', 177), ('madison', 174), ('fayetteville', 171), ('beach', 167), ('skibo', 158), ('video', 153), ('park', 148)]
#  — — — — — — — — —

# %%
# Helper function
def cluster_importance(mgp):
    '''returns a word-topic matrix[phi] where each value represents
    the word importance for that particular cluster; 
    phi[i][w] would be the importance of word w in topic i.
    '''
    n_z_w = mgp.cluster_word_distribution
    beta, V, K = mgp.beta, mgp.vocab_size, mgp.K
    phi = [{} for i in range(K)]        
    for z in range(K):
        for w in n_z_w[z]:
            phi[z][w] = (n_z_w[z][w]+beta)/(sum(n_z_w[z].values())+V*beta)
    return phi

# %%
# Helper function(s)
def get_topic_name(doc, topic_dict):
    '''returns the topic name string value from a dictionary of topics'''
    topic_desc = topic_dict[doc]
    return topic_desc

def topic_allocation(df, docs, mgp, topic_dict):
    '''allocates all topics to each document in original dataframe,
    adding two columns for cluster number and cluster description'''
    topic_allocations=[]
    for doc in tqdm(docs):
        topic_label, score = mgp.choose_best_label(doc)
        topic_allocations.append(topic_label)

    df['dominant_topic'] = topic_allocations
    
    df['topic_name'] = df.dominant_topic.apply(lambda x: get_topic_name(x, topic_dict))
    print('Complete. Number of documents with topic allocated: {}'.format(len(df)))

# %%
# Define dictionary topics in same sequential order 
# based on clusters and word distributions in STTM model above

topic_dict = {}
topic_names = ['health',
               'virus',
               '',
               '',
               'cancer and heart disease',
               'diet and excercise',
               'health and medical workers',
               'abortion',
               'vaping and cigarettes',
               'drug costs and opioid crisis']

for i, topic_num in enumerate(topic_indices):
    topic_dict[topic_num]=topic_names[i]
    
# Allocate topics to original dataframe 
topic_allocation(tweets_df, docs, mgp, topic_dict)
# Out:
# 100%|██████████| 129990/129990 [00:59<00:00, 2178.07it/s]
# Complete. Number of documents with topic allocated: 129990

# %%
tweets_df['num_clusters'] = 10
tweets_df[['clean_tweet', 'dominant_topic','topic_name']].sample(n=10)
# Out:
#                                               clean_tweet  dominant_topic  \
# 18074              family local meijer mask workers crazy               6
# 122609  right walmart size amazon hasten downfall main...               6
# 9313                               onion ring great value               2
# 4950                                     walmart childish               3
# 97152                        look clearance stuff walmart               3
# 122793         head point investigation reveal store head               6
# 43810        post photo publix greenwise market main olas               4
# 33519   think costco favorite know bird lunds time may...               2
# 43479   want shoot shoot people charge food chain deci...               6
# 71000                                   sample world heal               2
#
#                         topic_name
# 18074   health and medical workers
# 122609  health and medical workers
# 9313
# 4950
# 97152
# 122793  health and medical workers
# 43810     cancer and heart disease
# 33519
# 43479   health and medical workers
# 71000

# %% [markdown]
# ### Heat Map Visualizations by Year/User

# %%
# Re-index dataframe by user(news source)
reindexed_tweets = tweets_df['dominant_topic'] 
reindexed_tweets.index = tweets_df['username']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# F:\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# F:\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'username'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-998e8f660083> in <module>
#       1 # Re-index dataframe by user(news source)
#       2 reindexed_tweets = tweets_df['dominant_topic']
# ----> 3 reindexed_tweets.index = tweets_df['username']
#
# F:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# F:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'username'

# %%
from collections import Counter

# Helper function
def keys_to_counts(keys):
    '''
    returns a tuple of topic categories and their 
    accompanying magnitudes for a given list of keys
    '''
    count_pairs = sorted(Counter(keys).items(), reverse=False)
    categories = [pair[0] for pair in count_pairs]
    counts = [pair[1] for pair in count_pairs]
    return (categories, counts)

# %%
# Generate counts of tweets per topic across each news source
n_topics = mgp.K
news_sources = tweets_df['username'].unique() 

user_keys = []
for source in news_sources:
    user_keys.append(reindexed_tweets[source].values)
    
user_counts = []
for keys in user_keys:
    categories, counts = keys_to_counts(keys)
    user_counts.append(counts)

user_topic_counts = pd.DataFrame(np.array(user_counts), index=news_sources)
user_topic_counts.columns = ['Topic {}'.format(i) for i in range(n_topics)]
user_topic_counts

# %%
# Add column to sum total topics 
user_topic_counts['total_topics'] =  user_topic_counts.sum(axis=1)

# Convert topic counts to percentages for each news source 
user_topic_counts_ratio =  user_topic_counts.apply(lambda x: (x / user_topic_counts['total_topics']))
user_topic_counts_ratio = user_topic_counts_ratio.drop(columns=['total_topics'])
user_topic_counts_ratio

# %%
# Display heat map of topics vs news sources
fig, ax = plt.subplots(figsize=(14,10))
sns.set(font_scale=1)
sns.heatmap(user_topic_counts_ratio, cmap="YlGnBu", ax=ax);
plt.show()

# %%
# Convert date to datetime
tweets_df['date'] = pd.to_datetime(tweets_df['date'], errors='coerce')

# Add column for year
tweets_df['year'] = tweets_df['date'].dt.year

# %%
# Re-index dataframe by year
reindexed_tweets = tweets_df['dominant_topic']
reindexed_tweets.index = tweets_df['year']

# %%
# Generate counts of tweets per topic across years
n_topics = mgp.K
years_range = sorted(tweets_df['year'].unique(), reverse=False)

yearly_keys = []
for year in years_range:
    yearly_keys.append(reindexed_tweets[year].values)
    
yearly_counts = []
for keys in yearly_keys:
    categories, counts = keys_to_counts(keys)
    yearly_counts.append(counts)

yearly_topic_counts = pd.DataFrame(np.array(yearly_counts), index=range(2014,2020+1))
yearly_topic_counts.columns = ['Topic {}'.format(i) for i in range(n_topics)]

yearly_topic_counts

# %%
# Display heat map of topics vs years
fig, ax = plt.subplots(figsize=(14,10))
sns.heatmap(yearly_topic_counts, cmap="YlGnBu", ax=ax);
plt.show()
