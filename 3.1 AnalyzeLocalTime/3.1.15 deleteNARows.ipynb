# %% [markdown]
# ## Delete Rows(specific value in specific column)

# %%
import datetime
import json
import os
import requests

# %%
#csv add local_time column
import pandas as pd
df = pd.read_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv - Copy\fastFood_2019_2021_localTime_stateLevel_4_columns.csv",low_memory=False)

# %%
#working
pd.options.mode.chained_assignment = None
i=0

for row in df.iterrows():
    if  str(df['local_time'][i])[0:10]=="2022-01-20":  
        print(i,df['local_time'][i])
        df=df.drop([i],axis=0)
    #print(i)
    i+=1

df.to_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv - Copy\fastFood_2019_2021_localTime_stateLevel_4_columns_1.csv",encoding="utf_8_sig",index=False)
# Out:
# 0 2022-01-20T23:24:24
# 1 2022-01-20T23:18:01
# 2 2022-01-20T22:33:15
# 3 2022-01-20T22:32:22
# 4 2022-01-20T22:31:31
# 5 2022-01-20T20:12:08
# 6 2022-01-20T22:00:55
# 7 2022-01-20T22:56:29
# 8 2022-01-20T19:55:15
# 9 2022-01-20T19:48:56
# 10 2022-01-20T23:47:52
# 11 2022-01-20T23:35:39
# 12 2022-01-20T23:28:22
# 13 2022-01-20T23:24:49
# 14 2022-01-20T21:24:16
# 15 2022-01-20T21:15:28
# 16 2022-01-20T23:13:39
# 17 2022-01-20T23:05:48
# 18 2022-01-20T21:00:54
# 19 2022-01-20T22:58:50
# 20 2022-01-20T21:56:18
# 21 2022-01-20T21:56:16
# 22 2022-01-20T20:54:20
# 23 2022-01-20T20:51:25
# 24 2022-01-20T21:45:03
# 25 2022-01-20T22:45:00
# 26 2022-01-20T23:44:27
# 27 2022-01-20T23:38:41
# 28 2022-01-20T23:34:35
# 29 2022-01-20T23:34:26
# 30 2022-01-20T23:32:59
# 31 2022-01-20T20:27:23
# 32 2022-01-20T23:23:59
# 33 2022-01-20T23:21:04
# 34 2022-01-20T20:18:27
# 35 2022-01-20T22:18:22
# 36 2022-01-20T22:18:12
# 37 2022-01-20T20:17:25
# 38 2022-01-20T22:16:11
# 39 2022-01-20T23:15:36
# ...

# %%
df = pd.read_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_3_groccery\4.2 LocalTime 1CSV - Copy\grocery_2019_2021_localTime_stateLevel_4_columns.csv",low_memory=False)

# %%
pd.options.mode.chained_assignment = None
i=0

for row in df.iterrows():
    if  str(df['local_time'][i])[0:10]=="2022-01-20":  
        print(i,df['local_time'][i])
        df=df.drop([i],axis=0)
    #print(i)
    i+=1

df.to_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_3_groccery\4.2 LocalTime 1CSV - Copy\grocery_2019_2021_localTime_stateLevel_4_columns_1.csv",index=False)
# Out:
# 441334 2022-01-20T23:27:05
# 441335 2022-01-20T22:44:01
# 441336 2022-01-20T22:06:52
# 441337 2022-01-20T23:05:43
# 441338 2022-01-20T21:58:23
# 441339 2022-01-20T21:57:15
# 441340 2022-01-20T23:54:43
# 441341 2022-01-20T23:51:50
# 441342 2022-01-20T20:51:18
# 441343 2022-01-20T22:50:14
# 441344 2022-01-20T23:46:27
# 441345 2022-01-20T20:34:43
# 441346 2022-01-20T22:31:36
# 441347 2022-01-20T23:27:54
# 441348 2022-01-20T23:17:32
# 441349 2022-01-20T22:15:17
# 441350 2022-01-20T22:14:31
# 441351 2022-01-20T23:08:59
# 441352 2022-01-20T22:59:50
# 441353 2022-01-20T19:54:58
# 441354 2022-01-20T21:49:43
# 441355 2022-01-20T21:46:14
# 441356 2022-01-20T19:41:22
# 441357 2022-01-20T22:32:48
# 441358 2022-01-20T19:30:10
# 441359 2022-01-20T22:23:40
# 441360 2022-01-20T21:20:42
# 441361 2022-01-20T21:17:33
# 441362 2022-01-20T22:16:06
# 441363 2022-01-20T22:15:48
# 441364 2022-01-20T21:09:55
# 441365 2022-01-20T22:04:40
# 441366 2022-01-20T21:01:11
# 441367 2022-01-20T18:57:18
# ...

# %%
#working
pd.options.mode.chained_assignment = None
i=0

for row in df.iterrows():
    if  str(df['local_time'][i])[0]!="2":  
        print(i,df["created_at"][i],df['local_time'][i])
        df=df.drop([i],axis=0)
    #print(i)
    i+=1

df.to_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv - Copy\fastFood_2019_2021_localTime_stateLevel_4_columns.csv",encoding="utf_8_sig",index=False)

# %%
pd.options.mode.chained_assignment = None
i=0

for row in df.iterrows():
    if  str(df['local_time'][i])[0:10]=="2022-01-21":  
        print(i,df["created_at"][i],df['local_time'][i])
        df=df.drop([i],axis=0)
    #print(i)
    i+=1

df.to_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv/fastFood_2019_2021_localTime_stateLevel_4.csv",encoding="utf_8_sig",index=False)

import pandas as pd
df= pd.read_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv/fastFood_2019_2021_localTime_stateLevel_4.csv",low_memory=False)

# %%
pd.options.mode.chained_assignment = None
i=0

for row in df.iterrows():
    if  str(df['local_time'][i])[0:10]=="2019-01-18":  
        print(i,df["created_at"][i],df['local_time'][i])
        df=df.drop([i],axis=0)
    #print(i)
    i+=1

df.to_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv/fastFood_2019_2021_localTime_stateLevel_5.csv",encoding="utf_8_sig",index=False)

import pandas as pd
df= pd.read_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv/fastFood_2019_2021_localTime_stateLevel_5.csv",low_memory=False)

# %%
pd.options.mode.chained_assignment = None
i=0

for row in df.iterrows():
    if  str(df['local_time'][i])[0:10]=="2019-01-19":  
        print(i,df["created_at"][i],df['local_time'][i])
        df=df.drop([i],axis=0)
    #print(i)
    i+=1

df.to_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv/fastFood_2019_2021_localTime_stateLevel_6.csv",encoding="utf_8_sig",index=False)

import pandas as pd
df= pd.read_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv/fastFood_2019_2021_localTime_stateLevel_6.csv",low_memory=False)

# %%
#test
pd.options.mode.chained_assignment = None
i=0

for row in df.iterrows():
    if  str(df['local_time'][i])[0]!="2":  
        print(i,df["created_at"][i],df['local_time'][i])
        #data = data.drop(i)
    #print(i)
    i+=1

# %%
#test
pd.options.mode.chained_assignment = None
i=0

for row in df.iterrows():
    if  str(df['local_time'][i])[0:10]=="2022-01-21":  
        print(i,df["created_at"][i],df['local_time'][i])
        #df=df.drop([i],axis=0)
    #print(i)
    i+=1

# %%
pd.options.mode.chained_assignment = None
i=0

for row in df.iterrows():
    if  str(df['local_time'][i])[0:10]=="2022-01-22":  
        print(i,df["created_at"][i],df['local_time'][i])
        #df=df.drop([i],axis=0)
    #print(i)
    i+=1

# %%
pd.options.mode.chained_assignment = None
i=0

for row in df.iterrows():
    if  str(df['local_time'][i])[0:10]=="2019-01-18":  
        print(i,df["created_at"][i],df['local_time'][i])
        #df=df.drop([i],axis=0)
    #print(i)
    i+=1

# %%
pd.options.mode.chained_assignment = None
i=0

for row in df.iterrows():
    if  str(df['local_time'][i])[0:10]=="2019-01-19":  
        print(i,df["created_at"][i],df['local_time'][i])
        #df=df.drop([i],axis=0)
    #print(i)
    i+=1

# %%
df.to_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv/fastFood_2019_2021_localTime_stateLevel_2.csv",encoding="utf_8_sig",index=False)

# %%
import pandas as pd
df= pd.read_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv/fastFood_2019_2021_localTime_stateLevel_2.csv",low_memory=False)

# %%
df.to_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv/fastFood_2019_2021_localTime_stateLevel_3.csv",encoding="utf_8_sig",index=False)

# %%
import pandas as pd
df= pd.read_csv(r"E:\OneDrive - University of Georgia\Project\Data\tweet_data_2_food\4.2 LocaTime 1 csv/fastFood_2019_2021_localTime_stateLevel_3.csv",low_memory=False)
